# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, r2_score
import matplotlib.pyplot as plt
import os

# %%
curr_dir_path = os.getcwd()
main_dir_path = os.path.abspath(os.path.join(curr_dir_path, os.pardir))
data_dir_path = os.path.join(main_dir_path, 'data')
raw_data_dir_path = os.path.join(data_dir_path, 'raw_data')
processed_data_dir_path = os.path.join(data_dir_path, 'processed_data')
cw_dir_path = os.path.join(data_dir_path, 'cw')
emissions_data_dir_path = os.path.join(raw_data_dir_path, 'emissions_data')
iea_data_dir_path = os.path.join(raw_data_dir_path, 'IEA_climate_policy_data')

# %%
emissions_total_df = pd.read_csv(os.path.join(processed_data_dir_path, 'treatment_control_and_emissions_data.csv'))
agg_policies_emissions_df = pd.read_csv(os.path.join(processed_data_dir_path, 'agg_policies_and_emissions_data_by_country.csv'))

# %%
emissions_total_df
# Out:
#      iso3  year      country  policies_per_year  policies_last_3_years  \
# 0     AFG  2000  Afghanistan                  0                    0.0
# 1     AFG  2001  Afghanistan                  0                    0.0
# 2     AFG  2002  Afghanistan                  0                    0.0
# 3     AFG  2003  Afghanistan                  0                    0.0
# 4     AFG  2004  Afghanistan                  0                    0.0
# ...   ...   ...          ...                ...                    ...
# 3629  ZWE  2018     Zimbabwe                  0                    0.0
# 3630  ZWE  2019     Zimbabwe                  1                    0.0
# 3631  ZWE  2020     Zimbabwe                  0                    1.0
# 3632  ZWE  2021     Zimbabwe                  1                    1.0
# 3633  ZWE  2022     Zimbabwe                  0                    2.0
#
#              income_group  prev_year_emission  avg_emissions_prev_3_years  \
# 0              Low income                 NaN                         NaN
# 1              Low income           25.390391                   25.390391
# 2              Low income           23.723115                   24.556753
# 3              Low income           26.383509                   25.165672
# 4              Low income           27.071538                   25.726054
# ...                   ...                 ...                         ...
# 3629  Lower middle income           45.410983                   46.390136
# 3630  Lower middle income           47.509033                   46.277579
# 3631  Lower middle income           46.442562                   46.454193
# 3632  Lower middle income           44.576343                   46.175979
# 3633  Lower middle income           45.759664                   45.592856
#
#       gdp per capita  fdi net inflows (% of gdp)  industry size (% of gdp)  \
# 0         174.930991                    0.022119                 23.810127
# 1         138.706822                    0.022119                 23.810127
# 2         178.954088                    0.022119                 23.810127
# 3         198.871116                    0.022119                 22.710864
# 4         221.763654                   -0.013397                 26.226790
# ...              ...                         ...                       ...
# 3629     2271.853335                    2.101721                 31.037898
# 3630     1684.027904                    0.970160                 32.025947
# 3631     1730.413489                    0.559626                 32.767517
# 3632     1724.387731                    0.871791                 28.805586
# 3633     2040.552459                    1.027031                 39.691642
#
#       population density (people per sq km)  total_emissions
# 0                                 30.863847        25.390391
# 1                                 31.099929        23.723115
# 2                                 32.776961        26.383509
# 3                                 34.854344        27.071538
# 4                                 36.123230        27.128799
# ...                                     ...              ...
# 3629                              38.863777        47.509033
# 3630                              39.476200        46.442562
# 3631                              40.136714        44.576343
# 3632                              40.835492        45.759664
# 3633                              41.538209        46.423948
#
# [3634 rows x 13 columns]

# %%
agg_policies_emissions_df.head()
# Out:
#   iso3               country         income_group  avg_emissions  \
# 0  AFG           Afghanistan           Low income      34.967808
# 1  AGO                Angola  Lower middle income     130.803111
# 2  ALB               Albania  Upper middle income       9.892394
# 3  ARE  United Arab Emirates          High income     211.977407
# 4  ARG             Argentina  Upper middle income     424.588736
#
#    avg_policies_last_5_years  emission_pct_change  emission_change
# 0                   0.391304             0.514646        13.067067
# 1                   4.739130             0.227446        25.365705
# 2                   2.304348             0.073085         0.630193
# 3                   6.565217             1.428248       168.617154
# 4                  10.608696             0.086533        33.628259

# %% [markdown]
# ## Cleaning

# %%
# Drop unnecessary columns
emissions_total_df.drop(columns=['policies_per_year'], inplace=True)

# %%
# Check for missing values
missing_values = emissions_total_df.isnull().sum()
print("Missing values in emissions_total_df:")
print(missing_values[missing_values > 0])

# Check for missing values in agg_policies_emissions_df
missing_values = agg_policies_emissions_df.isnull().sum()
print("Missing values in agg_policies_emissions_df:")
print(missing_values[missing_values > 0])
# Out:
# Missing values in emissions_total_df:
# prev_year_emission            158
# avg_emissions_prev_3_years    158
# dtype: int64
# Missing values in agg_policies_emissions_df:
# Series([], dtype: int64)

# %%
# Drop null values in total emissions DataFrame
emissions_total_df.dropna(inplace=True)

# Reset index
emissions_total_df.reset_index(drop=True, inplace=True)

# %% [markdown]
# ## EDA

# %%
# Plot histograms of numeric columns
def plot_histograms(df, title):
    numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns
    df[numeric_cols].hist(bins=20, figsize=(15, 10))
    plt.suptitle(title)
    plt.show()

plot_histograms(emissions_total_df, 'Total Emissions DataFrame Histograms')
plot_histograms(agg_policies_emissions_df, 'Agg Policies and Emissions DataFrame Histograms')

# %%
# Plot scatter plots of numeric columns
def plot_scatter_matrix(df, title):
    numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns
    pd.plotting.scatter_matrix(df[numeric_cols], figsize=(20, 20), diagonal='kde')
    plt.suptitle(title)
    plt.show()
plot_scatter_matrix(emissions_total_df, 'Total Emissions DataFrame Scatter Matrix')
# plot_scatter_matrix(agg_policies_emissions_df, 'Agg Policies and Emissions DataFrame Scatter Matrix')

# %%
agg_policies_emissions_df.sort_values(by='emission_pct_change', ascending=False, inplace=True)
agg_policies_emissions_df.reset_index(drop=True, inplace=True)

# Add rank column
agg_policies_emissions_df['rank_pct'] = agg_policies_emissions_df.index + 1
agg_policies_emissions_df.head()
# Out:
#   iso3     country         income_group  avg_emissions  \
# 0  DMA    Dominica  Upper middle income      -1.021640
# 1  MNG    Mongolia  Lower middle income      17.703677
# 2  MYS    Malaysia  Upper middle income      53.847368
# 3  SEN     Senegal  Lower middle income       9.041215
# 4  SYC  Seychelles          High income       0.207767
#
#    avg_policies_last_5_years  emission_pct_change  emission_change  rank_pct
# 0                   0.478261           167.292001        -2.599087         1
# 1                   1.695652           156.470579        37.913701         2
# 2                   6.739130            38.630843       109.399556         3
# 3                   2.173913            13.051951        17.289837         4
# 4                   1.391304            11.846501         0.345386         5

# %%
agg_policies_emissions_df.sort_values(by='emission_change', ascending=False, inplace=True)
agg_policies_emissions_df.reset_index(drop=True, inplace=True)

# Add rank column
agg_policies_emissions_df['rank_absolute'] = agg_policies_emissions_df.index + 1
agg_policies_emissions_df.head()
# Out:
#   iso3                     country         income_group  avg_emissions  \
# 0  CHN  People's Republic of China  Upper middle income   10294.699549
# 1  IND                       India  Lower middle income    2644.678008
# 2  IDN                   Indonesia  Upper middle income    1448.021164
# 3  SAU                Saudi Arabia          High income     606.654647
# 4  IRN    Islamic Republic of Iran  Lower middle income     807.601288
#
#    avg_policies_last_5_years  emission_pct_change  emission_change  rank_pct  \
# 0                  38.521739             2.156335      9913.731419        17
# 1                  40.521739             1.144481      1938.873699        30
# 2                  19.739130             0.908809      1031.087643        41
# 3                   4.347826             1.294496       452.205666        27
# 4                   4.782609             0.779527       426.383361        52
#
#    rank_absolute
# 0              1
# 1              2
# 2              3
# 3              4
# 4              5

# %%
# Get top 50 countries with the highest and lowest avg emissions
top_emitter_countries = agg_policies_emissions_df.sort_values(by='avg_emissions', ascending=False).head(50)

# Reset index
top_emitter_countries.reset_index(drop=True, inplace=True)
top_emitter_countries.head()
# Out:
#   iso3                     country         income_group  avg_emissions  \
# 0  CHN  People's Republic of China  Upper middle income   10294.699549
# 1  USA               United States          High income    5724.806851
# 2  IND                       India  Lower middle income    2644.678008
# 3  BRA                      Brazil  Upper middle income    1910.755268
# 4  RUS          Russian Federation  Upper middle income    1679.563796
#
#    avg_policies_last_5_years  emission_pct_change  emission_change  rank_pct  \
# 0                  38.521739             2.156335      9913.731419        17
# 1                  79.695652            -0.177442     -1121.186369       147
# 2                  40.521739             1.144481      1938.873699        30
# 3                  16.347826            -0.180563      -369.285510       149
# 4                   9.739130             0.208954       341.217786       100
#
#    rank_absolute
# 0              1
# 1            190
# 2              2
# 3            189
# 4              7

# %%
top_policy_makers = agg_policies_emissions_df.sort_values(by='avg_policies_last_5_years', ascending=False).head(50)

# Reset index
top_policy_makers.reset_index(drop=True, inplace=True)
top_policy_makers.head()
# Out:
#   iso3                     country         income_group  avg_emissions  \
# 0  USA               United States          High income    5724.806851
# 1  CAN                      Canada          High income     726.135085
# 2  IND                       India  Lower middle income    2644.678008
# 3  CHN  People's Republic of China  Upper middle income   10294.699549
# 4  AUS                   Australia          High income     589.449485
#
#    avg_policies_last_5_years  emission_pct_change  emission_change  rank_pct  \
# 0                  79.695652            -0.177442     -1121.186369       147
# 1                  47.391304             0.114473        76.954151       108
# 2                  40.521739             1.144481      1938.873699        30
# 3                  38.521739             2.156335      9913.731419        17
# 4                  38.304348            -0.115993       -67.440656       141
#
#    rank_absolute
# 0            190
# 1             25
# 2              2
# 3              1
# 4            181

# %%
top_reduction_countries = agg_policies_emissions_df.sort_values(by='emission_change', ascending=False).head(50)
# Reset index
top_reduction_countries.reset_index(drop=True, inplace=True)
top_reduction_countries.head()
# Out:
#   iso3                     country         income_group  avg_emissions  \
# 0  CHN  People's Republic of China  Upper middle income   10294.699549
# 1  IND                       India  Lower middle income    2644.678008
# 2  IDN                   Indonesia  Upper middle income    1448.021164
# 3  SAU                Saudi Arabia          High income     606.654647
# 4  IRN    Islamic Republic of Iran  Lower middle income     807.601288
#
#    avg_policies_last_5_years  emission_pct_change  emission_change  rank_pct  \
# 0                  38.521739             2.156335      9913.731419        17
# 1                  40.521739             1.144481      1938.873699        30
# 2                  19.739130             0.908809      1031.087643        41
# 3                   4.347826             1.294496       452.205666        27
# 4                   4.782609             0.779527       426.383361        52
#
#    rank_absolute
# 0              1
# 1              2
# 2              3
# 3              4
# 4              5

# %%
# Merge top emitters with top policy makers
merge_df = pd.merge(top_emitter_countries, top_policy_makers, on='country')
best_countries = merge_df['iso3_x'].tolist()
len(best_countries)
# Out:
# 28

# %%
# Filter the DataFrame to include only the best countries
best_countries_df = agg_policies_emissions_df[agg_policies_emissions_df['iso3'].isin(best_countries)]
# Reset index
best_countries_df.reset_index(drop=True, inplace=True)
best_countries_df.head()
# Out:
#   iso3                     country         income_group  avg_emissions  \
# 0  CHN  People's Republic of China  Upper middle income   10294.699549
# 1  IND                       India  Lower middle income    2644.678008
# 2  IDN                   Indonesia  Upper middle income    1448.021164
# 3  TUR                     Turkiye  Upper middle income     388.202551
# 4  RUS          Russian Federation  Upper middle income    1679.563796
#
#    avg_policies_last_5_years  emission_pct_change  emission_change  rank_pct  \
# 0                  38.521739             2.156335      9913.731419        17
# 1                  40.521739             1.144481      1938.873699        30
# 2                  19.739130             0.908809      1031.087643        41
# 3                  14.391304             1.414567       369.036863        25
# 4                   9.739130             0.208954       341.217786       100
#
#    rank_absolute
# 0              1
# 1              2
# 2              3
# 3              6
# 4              7

# %%
plot_histograms(best_countries_df, 'Best Countries DataFrame Histograms')

# %%
plot_scatter_matrix(best_countries_df, 'Best Countries DataFrame Scatter Matrix')

# %% [markdown]
# ## Preprocess Data

# %%
# Filter the emissions dataset to include only the best countries
best_countries_emissions_df = emissions_total_df[emissions_total_df['iso3'].isin(best_countries)]
# Reset index
best_countries_emissions_df.reset_index(drop=True, inplace=True)
best_countries_emissions_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 572 entries, 0 to 571
# Data columns (total 12 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   iso3                                   572 non-null    object
#  1   year                                   572 non-null    int64
#  2   country                                572 non-null    object
#  3   policies_last_3_years                  572 non-null    float64
#  4   income_group                           572 non-null    object
#  5   prev_year_emission                     572 non-null    float64
#  6   avg_emissions_prev_3_years             572 non-null    float64
#  7   gdp per capita                         572 non-null    float64
#  8   fdi net inflows (% of gdp)             572 non-null    float64
#  9   industry size (% of gdp)               572 non-null    float64
#  10  population density (people per sq km)  572 non-null    float64
#  11  total_emissions                        572 non-null    float64
# dtypes: float64(8), int64(1), object(3)
# memory usage: 53.8+ KB

# %%
# Drop iso3 and year columns
best_countries_emissions_df = best_countries_emissions_df.drop(columns=['iso3', 'country'])

# %%
# Scale the data
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
# Select numeric columns for scaling
numeric_cols = best_countries_emissions_df.select_dtypes(include=['float64', 'int64']).columns

# Remove the 'year' column from the list of numeric columns
if 'year' in numeric_cols:
    numeric_cols = numeric_cols.drop('year')

# Scale the numeric columns
best_countries_emissions_df[numeric_cols] = scaler.fit_transform(best_countries_emissions_df[numeric_cols])

# %% [markdown]
# ## Define Functions

# %%
def time_series_train_test_split(df, target, features, split_year, income_subset=None):
    
    if income_subset:
        test = df[(df.income_group.isin(income_subset)) & (df['year'] > split_year)]
    else:
        test = df[df['year'] > split_year]
    
    train = df[df['year'] <= split_year]

    # Drop year columns
    train = train.drop(columns=['year'])
    test = test.drop(columns=['year'])
    

    print(f"Train shape: {train.shape}")
    print(f"Test shape: {test.shape}")

    print(f'train / test split: {train.shape[0] / df.shape[0]} / {test.shape[0] / df.shape[0]}')

    X_train, y_train = train[features], train[target]
    X_test, y_test = test[features], test[target]

    return X_train, y_train, X_test, y_test

# %%
def simple_rf_regressor(X_train, y_train, X_test, y_test):
    model = RandomForestRegressor(n_estimators=100, random_state=42)
    model.fit(X_train, y_train)

    preds = model.predict(X_test)
    print("MAE:", mean_absolute_error(y_test, preds))
    print("R²:", r2_score(y_test, preds))

    # Scatter plot of actual vs predicted
    plt.scatter(y_test, preds)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.show()
    

    return model

# %%
def train_and_test_model(df, target, features, split_year=2017, income_subset=None):
    X_train, y_train, X_test, y_test = time_series_train_test_split(df, target, features, split_year, income_subset)
    model = simple_rf_regressor(X_train, y_train, X_test, y_test)
    importance = pd.Series(model.feature_importances_, index=features)
    print(importance.sort_values(ascending=False))
    importance.sort_values(ascending=False).plot(kind='barh')
    
    return model

# %% [markdown]
# ## Train Models

# %%
best_countries_emissions_df.head()
# Out:
#    year  policies_last_3_years income_group  prev_year_emission  \
# 0  2001              -0.790086  High income           -0.650596
# 1  2002              -0.853346  High income           -0.638681
# 2  2003              -0.853346  High income           -0.637778
# 3  2004              -0.726826  High income           -0.631169
# 4  2005              -0.726826  High income           -0.625580
#
#    avg_emissions_prev_3_years  gdp per capita  fdi net inflows (% of gdp)  \
# 0                   -0.648047        0.241183                   -0.483866
# 1                   -0.642099        0.241629                   -0.455646
# 2                   -0.639815        0.342431                   -0.398376
# 3                   -0.633350        0.539026                   -0.297484
# 4                   -0.628989        0.821588                   -0.213084
#
#    industry size (% of gdp)  population density (people per sq km)  \
# 0                  2.870482                              -0.664300
# 1                  2.593790                              -0.640553
# 2                  2.798363                              -0.616561
# 3                  3.130474                              -0.592480
# 4                  3.645408                              -0.568469
#
#    total_emissions
# 0        -0.642444
# 1        -0.641540
# 2        -0.634918
# 3        -0.629317
# 4        -0.621398

# %%
emissions_total_df.head()
# Out:
#   iso3  year      country  policies_last_3_years income_group  \
# 0  AFG  2001  Afghanistan                    0.0   Low income
# 1  AFG  2002  Afghanistan                    0.0   Low income
# 2  AFG  2003  Afghanistan                    0.0   Low income
# 3  AFG  2004  Afghanistan                    0.0   Low income
# 4  AFG  2005  Afghanistan                    0.0   Low income
#
#    prev_year_emission  avg_emissions_prev_3_years  gdp per capita  \
# 0           25.390391                   25.390391      138.706822
# 1           23.723115                   24.556753      178.954088
# 2           26.383509                   25.165672      198.871116
# 3           27.071538                   25.726054      221.763654
# 4           27.128799                   26.861282      254.184249
#
#    fdi net inflows (% of gdp)  industry size (% of gdp)  \
# 0                    0.022119                 23.810127
# 1                    0.022119                 23.810127
# 2                    0.022119                 22.710864
# 3                   -0.013397                 26.226790
# 4                    0.024181                 26.812099
#
#    population density (people per sq km)  total_emissions
# 0                              31.099929        23.723115
# 1                              32.776961        26.383509
# 2                              34.854344        27.071538
# 3                              36.123230        27.128799
# 4                              37.417118        27.530896

# %% [markdown]
# ### Prediction Model

# %%
emissions_total_df.drop(columns=['iso3', 'country'], inplace=True)
target = 'total_emissions'
features = emissions_total_df.drop(columns=['total_emissions', 'income_group', 'year']).columns
train_and_test_model(emissions_total_df, target, features)
# Out:
# Train shape: (2686, 9)
# Test shape: (790, 9)
# train / test split: 0.7727272727272727 / 0.22727272727272727
# MAE: 10.633343403512422
# R²: 0.9947019646032776
# prev_year_emission                       0.659164
# avg_emissions_prev_3_years               0.304262
# gdp per capita                           0.017296
# industry size (% of gdp)                 0.015732
# population density (people per sq km)    0.002149
# fdi net inflows (% of gdp)               0.000928
# policies_last_3_years                    0.000469
# dtype: float64
# RandomForestRegressor(random_state=42)

# %%
emissions_total_df.income_group.unique()
# Out:
# array(['Low income', 'Lower middle income', 'Upper middle income',
#        'High income'], dtype=object)

# %%
train_and_test_model(emissions_total_df, target, features, income_subset=['Low income'])
# Out:
# Train shape: (2850, 7)
# Test shape: (175, 7)
# train / test split: 0.6818181818181818 / 0.041866028708133975
# MAE: 2.0560679844632133
# R²: 0.9976140798216371
# prev_year_emission            0.510975
# avg_emissions_prev_3_years    0.485984
# policies_last_5_years         0.003041
# dtype: float64
# RandomForestRegressor(random_state=42)

# %%
train_and_test_model(emissions_total_df, target, features, income_subset=['Lower middle income'])
# Out:
# Train shape: (3230, 9)
# Test shape: (265, 9)
# train / test split: 0.7727272727272727 / 0.06339712918660287
# MAE: 12.802501413223704
# R²: 0.98797546380266
# prev_year_emission                    0.560769
# avg_emissions_prev_3_years            0.432721
# year                                  0.002405
# policy_intensity_vs_emission_level    0.001893
# policy_trend_lag_interaction          0.001532
# policies_last_3_years                 0.000681
# dtype: float64
# RandomForestRegressor(random_state=42)

# %%
train_and_test_model(emissions_total_df, target, features, income_subset=['Upper middle income'])
# Out:
# Train shape: (3230, 9)
# Test shape: (240, 9)
# train / test split: 0.7727272727272727 / 0.05741626794258373
# MAE: 41.088158836671134
# R²: 0.987045833069964
# prev_year_emission                    0.560769
# avg_emissions_prev_3_years            0.432721
# year                                  0.002405
# policy_intensity_vs_emission_level    0.001893
# policy_trend_lag_interaction          0.001532
# policies_last_3_years                 0.000681
# dtype: float64
# RandomForestRegressor(random_state=42)

# %%
train_and_test_model(emissions_total_df, target, features, income_subset=['High income'])
# Out:
# Train shape: (3230, 9)
# Test shape: (320, 9)
# train / test split: 0.7727272727272727 / 0.07655502392344497
# MAE: 12.841585612350087
# R²: 0.9946362676163895
# prev_year_emission                    0.560769
# avg_emissions_prev_3_years            0.432721
# year                                  0.002405
# policy_intensity_vs_emission_level    0.001893
# policy_trend_lag_interaction          0.001532
# policies_last_3_years                 0.000681
# dtype: float64
# RandomForestRegressor(random_state=42)
