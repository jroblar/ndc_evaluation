# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LassoCV, ElasticNetCV, LinearRegression
# from ngboost import NGBRegressor
from sklearn.model_selection import GroupKFold, cross_val_score
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.linear_model import lasso_path

from utils.eda_utils import EDAUtils, FeatureEngineering, DataCleaningUtils
from utils.ml_utils_v2 import RegressionAnalysis

# %%
# %load_ext autoreload
# %autoreload 2

# %%
eda_utils = EDAUtils()
dcu = DataCleaningUtils()
fe = FeatureEngineering()

# %%
SCRIPT_DIR_PATH = os.getcwd()
ROOT_DIR_PATH = os.path.dirname(SCRIPT_DIR_PATH)
DATA_DIR_PATH = os.path.join(ROOT_DIR_PATH, "data")
PROCESSED_DATA_DIR_PATH = os.path.join(DATA_DIR_PATH, "processed_data")
RESULTS_DIR_PATH = os.path.join(SCRIPT_DIR_PATH, "results")

# %%
# Load the emissions data
emissions_df = pd.read_csv(os.path.join(PROCESSED_DATA_DIR_PATH, "total_emissions.csv"))
emissions_df.head()
# Out:
#   iso_alpha_3 income_group                     region  year  total_emissions
# 0         ABW  High income  Latin America & Caribbean  2000         0.335765
# 1         ABW  High income  Latin America & Caribbean  2001         0.344135
# 2         ABW  High income  Latin America & Caribbean  2002         0.363222
# 3         ABW  High income  Latin America & Caribbean  2003         0.412246
# 4         ABW  High income  Latin America & Caribbean  2004         0.430187

# %%
emissions_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4485 entries, 0 to 4484
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   iso_alpha_3      4485 non-null   object
#  1   income_group     4485 non-null   object
#  2   region           4485 non-null   object
#  3   year             4485 non-null   int64
#  4   total_emissions  4485 non-null   float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 175.3+ KB

# %%
# Load the wb controls
wb_df = pd.read_csv(os.path.join(PROCESSED_DATA_DIR_PATH, "wb_indicators.csv"))
wb_df.head()
# Out:
#    year    pop_total  electricity_from_renewables_pct  \
# 0  2022  731821393.0                              NaN
# 1  2021  713090928.0                         4.939318
# 2  2020  694446100.0                         4.585792
# 3  2019  675950189.0                         5.173796
# 4  2018  657801085.0                         3.945917
#
#    renewable_energy_consumption_pct  forest_area_pct  gdp_2015_usd  \
# 0                               NaN        29.737205  1.040350e+12
# 1                               NaN        29.955194  1.004646e+12
# 2                         66.123449        30.174252  9.606813e+11
# 3                         63.387090        30.391626  9.890095e+11
# 4                         62.242631        30.611512  9.677734e+11
#
#    imports_2015_usd  industry_value_added_2015_usd  \
# 0      3.196559e+11                   2.535995e+11
# 1      2.769094e+11                   2.468588e+11
# 2      2.448648e+11                   2.363776e+11
# 3      2.770649e+11                   2.482358e+11
# 4      2.838657e+11                   2.437429e+11
#
#    manufacturing_value_added_2015_usd  exports_2015_usd iso_alpha_3
# 0                        1.016612e+11      2.360208e+11         NaN
# 1                        9.989399e+10      2.143081e+11         NaN
# 2                        9.446765e+10      1.958722e+11         NaN
# 3                        1.014837e+11      2.217922e+11         NaN
# 4                        1.002104e+11      2.275611e+11         NaN

# %%
wb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6118 entries, 0 to 6117
# Data columns (total 11 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   year                                6118 non-null   int64
#  1   pop_total                           6095 non-null   float64
#  2   electricity_from_renewables_pct     5617 non-null   float64
#  3   renewable_energy_consumption_pct    5710 non-null   float64
#  4   forest_area_pct                     5953 non-null   float64
#  5   gdp_2015_usd                        5832 non-null   float64
#  6   imports_2015_usd                    4449 non-null   float64
#  7   industry_value_added_2015_usd       5254 non-null   float64
#  8   manufacturing_value_added_2015_usd  4733 non-null   float64
#  9   exports_2015_usd                    4413 non-null   float64
#  10  iso_alpha_3                         4945 non-null   object
# dtypes: float64(9), int64(1), object(1)
# memory usage: 525.9+ KB

# %%
indicators_and_emissions_df = pd.merge(emissions_df, wb_df, on=["iso_alpha_3", "year"], how="left")
indicators_and_emissions_df.head()
# Out:
#   iso_alpha_3 income_group                     region  year  total_emissions  \
# 0         ABW  High income  Latin America & Caribbean  2000         0.335765
# 1         ABW  High income  Latin America & Caribbean  2001         0.344135
# 2         ABW  High income  Latin America & Caribbean  2002         0.363222
# 3         ABW  High income  Latin America & Caribbean  2003         0.412246
# 4         ABW  High income  Latin America & Caribbean  2004         0.430187
#
#    pop_total  electricity_from_renewables_pct  \
# 0    90588.0                              0.0
# 1    91439.0                              0.0
# 2    92074.0                              0.0
# 3    93128.0                              0.0
# 4    95138.0                              0.0
#
#    renewable_energy_consumption_pct  forest_area_pct  gdp_2015_usd  \
# 0                               0.2         2.333333  2.735727e+09
# 1                               0.2         2.333333  2.850135e+09
# 2                               0.2         2.333333  2.823203e+09
# 3                               0.2         2.333333  2.854554e+09
# 4                               0.2         2.333333  3.062758e+09
#
#    imports_2015_usd  industry_value_added_2015_usd  \
# 0               NaN                            NaN
# 1               NaN                            NaN
# 2               NaN                            NaN
# 3               NaN                            NaN
# 4               NaN                            NaN
#
#    manufacturing_value_added_2015_usd  exports_2015_usd
# 0                                 NaN               NaN
# 1                                 NaN               NaN
# 2                                 NaN               NaN
# 3                                 NaN               NaN
# 4                                 NaN               NaN

# %%
# move total_emissions to the end
indicators_and_emissions_df = indicators_and_emissions_df[[col for col in indicators_and_emissions_df.columns if col != "total_emissions"] + ["total_emissions"]]
indicators_and_emissions_df.head()
# Out:
#   iso_alpha_3 income_group                     region  year  pop_total  \
# 0         ABW  High income  Latin America & Caribbean  2000    90588.0
# 1         ABW  High income  Latin America & Caribbean  2001    91439.0
# 2         ABW  High income  Latin America & Caribbean  2002    92074.0
# 3         ABW  High income  Latin America & Caribbean  2003    93128.0
# 4         ABW  High income  Latin America & Caribbean  2004    95138.0
#
#    electricity_from_renewables_pct  renewable_energy_consumption_pct  \
# 0                              0.0                               0.2
# 1                              0.0                               0.2
# 2                              0.0                               0.2
# 3                              0.0                               0.2
# 4                              0.0                               0.2
#
#    forest_area_pct  gdp_2015_usd  imports_2015_usd  \
# 0         2.333333  2.735727e+09               NaN
# 1         2.333333  2.850135e+09               NaN
# 2         2.333333  2.823203e+09               NaN
# 3         2.333333  2.854554e+09               NaN
# 4         2.333333  3.062758e+09               NaN
#
#    industry_value_added_2015_usd  manufacturing_value_added_2015_usd  \
# 0                            NaN                                 NaN
# 1                            NaN                                 NaN
# 2                            NaN                                 NaN
# 3                            NaN                                 NaN
# 4                            NaN                                 NaN
#
#    exports_2015_usd  total_emissions
# 0               NaN         0.335765
# 1               NaN         0.344135
# 2               NaN         0.363222
# 3               NaN         0.412246
# 4               NaN         0.430187

# %%
indicators_and_emissions_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4485 entries, 0 to 4484
# Data columns (total 14 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   iso_alpha_3                         4485 non-null   object
#  1   income_group                        4485 non-null   object
#  2   region                              4485 non-null   object
#  3   year                                4485 non-null   int64
#  4   pop_total                           4462 non-null   float64
#  5   electricity_from_renewables_pct     4216 non-null   float64
#  6   renewable_energy_consumption_pct    4324 non-null   float64
#  7   forest_area_pct                     4402 non-null   float64
#  8   gdp_2015_usd                        4317 non-null   float64
#  9   imports_2015_usd                    3431 non-null   float64
#  10  industry_value_added_2015_usd       4032 non-null   float64
#  11  manufacturing_value_added_2015_usd  3743 non-null   float64
#  12  exports_2015_usd                    3431 non-null   float64
#  13  total_emissions                     4485 non-null   float64
# dtypes: float64(10), int64(1), object(3)
# memory usage: 490.7+ KB

# %% [markdown]
# ## Data Cleaning

# %%
# Fill missing values for numeric columns
indicators_and_emissions_df = dcu.fill_numeric_missing_by_group(indicators_and_emissions_df, ["iso_alpha_3"])

# %%
indicators_and_emissions_df.describe()
# Out:
#               year     pop_total  electricity_from_renewables_pct  \
# count  4485.000000  4.485000e+03                      4485.000000
# mean   2011.000000  3.621556e+07                         5.026383
# std       6.633989  1.361826e+08                        10.405182
# min    2000.000000  1.764800e+04                       -71.056856
# 25%    2005.000000  1.504365e+06                         0.034592
# 50%    2011.000000  7.223805e+06                         1.286178
# 75%    2017.000000  2.486266e+07                         5.805103
# max    2022.000000  1.425423e+09                        97.277228
#
#        renewable_energy_consumption_pct  forest_area_pct  gdp_2015_usd  \
# count                       4485.000000      4485.000000  4.485000e+03
# mean                          31.618974        32.197366  3.471272e+11
# std                           30.027298        24.132037  1.496928e+12
# min                            0.000000         0.000000  1.324972e+08
# 25%                            5.600000        11.073684  6.876350e+09
# 50%                           21.600000        30.442858  2.702675e+10
# 75%                           53.300000        50.935065  1.796832e+11
# max                           98.300000        95.577213  2.144339e+13
#
#        imports_2015_usd  industry_value_added_2015_usd  \
# count      4.485000e+03                   4.485000e+03
# mean       1.045265e+11                   9.345957e+10
# std        2.760113e+11                   3.884098e+11
# min        7.145490e+07                   9.434428e+06
# 25%        4.034603e+09                   1.449723e+09
# 50%        1.441437e+10                   7.594740e+09
# 75%        7.079266e+10                   5.265770e+10
# max        3.542496e+12                   6.430542e+12
#
#        manufacturing_value_added_2015_usd  exports_2015_usd  total_emissions
# count                        4.485000e+03      4.485000e+03      4485.000000
# mean                         6.058097e+10      1.069587e+11       221.511989
# std                          2.862916e+11      2.731760e+11       920.296951
# min                          1.685068e+06      8.775953e+06      -242.690846
# 25%                          5.731685e+08      2.856089e+09         3.405074
# 50%                          3.167052e+09      1.240303e+10        36.933154
# 75%                          2.542704e+10      7.291426e+10       116.330198
# max                          3.202510e+12      2.456083e+12     14511.221700

# %%
# Check which rows have negative electricity_from_renewables_pct
indicators_and_emissions_df[indicators_and_emissions_df["electricity_from_renewables_pct"] < 0]["iso_alpha_3"].unique()
# Out:
# array(['AGO', 'ARG', 'ARM', 'BEN', 'BFA', 'BGD', 'BOL', 'CIV', 'CMR',
#        'COD', 'COG', 'COL', 'DZA', 'ECU', 'EGY', 'ETH', 'GAB', 'GEO',
#        'GNQ', 'HRV', 'IND', 'IRN', 'IRQ', 'JAM', 'KAZ', 'KEN', 'KGZ',
#        'KHM', 'LAO', 'LBN', 'MDG', 'MKD', 'MNG', 'MOZ', 'MYS', 'NAM',
#        'NGA', 'NPL', 'PAK', 'PRK', 'PRY', 'SDN', 'SUR', 'TGO', 'TJK',
#        'TKM', 'TUN', 'TZA', 'UGA', 'UZB', 'VNM', 'ZAF', 'ZMB'],
#       dtype=object)

# %%
# Drop electricity_from_renewables_pct column
indicators_and_emissions_df = indicators_and_emissions_df.drop(columns=["electricity_from_renewables_pct"])

# %%
# Check negative emissions
negative_emissions_df = indicators_and_emissions_df[indicators_and_emissions_df["total_emissions"] < 0]
negative_emissions_df.iso_alpha_3.unique()
# Out:
# array(['BDI', 'BHS', 'BLZ', 'BTN', 'CAF', 'CMR', 'COG', 'COM', 'DJI',
#        'DMA', 'GAB', 'GRD', 'GTM', 'KNA', 'LBR', 'LVA', 'MLI', 'MNG',
#        'NAM', 'NER', 'PAN', 'PNG', 'RWA', 'STP', 'SWZ', 'TLS', 'TON',
#        'VUT', 'WSM'], dtype=object)

# %%
# Drop the negative emissions
indicators_and_emissions_df =indicators_and_emissions_df[indicators_and_emissions_df["total_emissions"] >= 0]

# %%
# Check for duplicates
duplicates_df = indicators_and_emissions_df[indicators_and_emissions_df.duplicated(subset=["iso_alpha_3", "year"], keep=False)]
duplicates_df = duplicates_df.sort_values(by=["iso_alpha_3", "year"])
print(f"Duplicates: {duplicates_df.shape[0]}")
print(duplicates_df)
# Out:
# Duplicates: 0
# Empty DataFrame
# Columns: [iso_alpha_3, income_group, region, year, pop_total, renewable_energy_consumption_pct, forest_area_pct, gdp_2015_usd, imports_2015_usd, industry_value_added_2015_usd, manufacturing_value_added_2015_usd, exports_2015_usd, total_emissions]
# Index: []

# %%
# Check how many records we have per iso_alpha_3 and create a new df
# with the number of records per iso_alpha_3
iso_alpha_3_counts = indicators_and_emissions_df["iso_alpha_3"].value_counts().reset_index()
iso_alpha_3_counts.columns = ["iso_alpha_3", "count"]
iso_alpha_3_counts = iso_alpha_3_counts.sort_values(by="count", ascending=False)

# how many countries have less than x records?
x = 23
countries_with_less_than_x_records = iso_alpha_3_counts[iso_alpha_3_counts["count"] < x]
print(f"Countries with less than {x} records: {countries_with_less_than_x_records.shape[0]}")
print(countries_with_less_than_x_records)
# Out:
# Countries with less than 23 records: 14
#     iso_alpha_3  count
# 166         GTM     22
# 167         TLS     22
# 168         LVA     20
# 169         MNG     18
# 170         RWA     17
# 171         BDI     17
# 172         GRD     15
# 173         COG     14
# 174         KNA     12
# 175         DJI     10
# 176         PNG      9
# 177         PAN      8
# 178         DMA      6
# 179         NER      5

# %%
# Remove the countries with less than x records from the indicators_and_emissions_df
countries_to_remove = countries_with_less_than_x_records["iso_alpha_3"].tolist()
indicators_and_emissions_df = indicators_and_emissions_df[~indicators_and_emissions_df["iso_alpha_3"].isin(countries_to_remove)]
indicators_and_emissions_df = indicators_and_emissions_df.reset_index(drop=True)

# %%
# Check the max year for every country
max_year_df = indicators_and_emissions_df.groupby("iso_alpha_3")["year"].max().reset_index()
max_year_df.columns = ["iso_alpha_3", "max_year"]
max_year_df = max_year_df.sort_values(by="max_year", ascending=False)
print(max_year_df.max_year.unique())
# Out:
# [2022]

# %%
indicators_and_emissions_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 13 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   iso_alpha_3                         3818 non-null   object
#  1   income_group                        3818 non-null   object
#  2   region                              3818 non-null   object
#  3   year                                3818 non-null   int64
#  4   pop_total                           3818 non-null   float64
#  5   renewable_energy_consumption_pct    3818 non-null   float64
#  6   forest_area_pct                     3818 non-null   float64
#  7   gdp_2015_usd                        3818 non-null   float64
#  8   imports_2015_usd                    3818 non-null   float64
#  9   industry_value_added_2015_usd       3818 non-null   float64
#  10  manufacturing_value_added_2015_usd  3818 non-null   float64
#  11  exports_2015_usd                    3818 non-null   float64
#  12  total_emissions                     3818 non-null   float64
# dtypes: float64(9), int64(1), object(3)
# memory usage: 387.9+ KB

# %%
indicators_and_emissions_df[indicators_and_emissions_df["iso_alpha_3"] == "AGO"].sort_values(by="year")
# Out:
#    iso_alpha_3         income_group                       region  year  \
# 67         AGO  Lower middle income  Africa Eastern and Southern  2000
# 66         AGO  Lower middle income  Africa Eastern and Southern  2001
# 65         AGO  Lower middle income  Africa Eastern and Southern  2002
# 64         AGO  Lower middle income  Africa Eastern and Southern  2003
# 63         AGO  Lower middle income  Africa Eastern and Southern  2004
# 62         AGO  Lower middle income  Africa Eastern and Southern  2005
# 61         AGO  Lower middle income  Africa Eastern and Southern  2006
# 60         AGO  Lower middle income  Africa Eastern and Southern  2007
# 59         AGO  Lower middle income  Africa Eastern and Southern  2008
# 58         AGO  Lower middle income  Africa Eastern and Southern  2009
# 68         AGO  Lower middle income  Africa Eastern and Southern  2010
# 57         AGO  Lower middle income  Africa Eastern and Southern  2011
# 47         AGO  Lower middle income  Africa Eastern and Southern  2012
# 56         AGO  Lower middle income  Africa Eastern and Southern  2013
# 55         AGO  Lower middle income  Africa Eastern and Southern  2014
# 54         AGO  Lower middle income  Africa Eastern and Southern  2015
# 53         AGO  Lower middle income  Africa Eastern and Southern  2016
# 52         AGO  Lower middle income  Africa Eastern and Southern  2017
# 51         AGO  Lower middle income  Africa Eastern and Southern  2018
# 50         AGO  Lower middle income  Africa Eastern and Southern  2019
# 49         AGO  Lower middle income  Africa Eastern and Southern  2020
# 48         AGO  Lower middle income  Africa Eastern and Southern  2021
# 46         AGO  Lower middle income  Africa Eastern and Southern  2022
#
#      pop_total  renewable_energy_consumption_pct  forest_area_pct  \
# 67  16194869.0                              73.8        62.331443
# 66  16747208.0                              72.8        61.886219
# 65  17327699.0                              70.8        61.440995
# 64  17943712.0                              65.6        60.995770
# 63  18600423.0                              62.3        60.550546
# 62  19291161.0                              68.9        60.105322
# 61  20015279.0                              62.6        59.660098
# 60  20778561.0                              58.9        59.214874
# 59  21578655.0                              55.4        58.769649
# 58  22414773.0                              53.0        58.324425
# 68  23294825.0                              53.1        57.879201
# 57  24218352.0                              51.7        57.433976
# 47  25177394.0                              49.0        56.988751
# 56  26165620.0                              46.8        56.543526
# 55  27160769.0                              47.5        56.098301
# 54  28157798.0                              47.1        55.653076
# 53  29183070.0                              48.1        55.207845
# 52  30234839.0                              52.5        54.762629
# 51  31297155.0                              52.5        54.317406
# 50  32375632.0                              51.0        53.872175
# 49  33451132.0                              60.1        53.426951
# 48  34532429.0                              52.9        52.981722
# 46  35635029.0                              49.0        52.536497
#
#     gdp_2015_usd  imports_2015_usd  industry_value_added_2015_usd  \
# 67  3.130450e+10      2.298069e+10                   1.621840e+10
# 66  3.262116e+10      2.298069e+10                   1.621840e+10
# 65  3.707907e+10      2.298069e+10                   1.621840e+10
# 64  3.818773e+10      2.520752e+10                   1.620435e+10
# 63  4.236929e+10      2.700481e+10                   1.860275e+10
# 62  4.873739e+10      3.023189e+10                   2.241556e+10
# 61  5.436656e+10      3.215161e+10                   2.537292e+10
# 60  6.198332e+10      3.459513e+10                   3.039648e+10
# 59  6.890685e+10      4.088107e+10                   3.330444e+10
# 58  6.949945e+10      4.068712e+10                   3.200557e+10
# 68  7.255630e+10      3.591116e+10                   3.197610e+10
# 57  7.507549e+10      3.984345e+10                   3.128685e+10
# 47  8.148852e+10      3.980781e+10                   3.457634e+10
# 56  8.552596e+10      4.155085e+10                   3.560264e+10
# 55  8.965050e+10      3.940746e+10                   3.504457e+10
# 54  9.049642e+10      2.998501e+10                   3.794795e+10
# 53  8.816157e+10      2.256705e+10                   3.770875e+10
# 52  8.803178e+10      2.510203e+10                   3.650684e+10
# 51  8.687297e+10      2.109186e+10                   3.423869e+10
# 50  8.626288e+10      1.580866e+10                   3.304787e+10
# 49  8.139919e+10      1.237904e+10                   2.959055e+10
# 48  8.237534e+10      1.190661e+10                   2.712328e+10
# 46  8.488345e+10      1.501539e+10                   2.760259e+10
#
#     manufacturing_value_added_2015_usd  exports_2015_usd  total_emissions
# 67                        2.255448e+09      1.653568e+10       111.523943
# 66                        2.255448e+09      1.653568e+10       109.364994
# 65                        2.255448e+09      1.653568e+10       108.114862
# 64                        2.376152e+09      1.632072e+10       108.366595
# 63                        2.770014e+09      1.845710e+10       114.489712
# 62                        2.939686e+09      2.268931e+10       113.596505
# 61                        3.132186e+09      2.593161e+10       106.468040
# 60                        3.195348e+09      3.022589e+10       105.871055
# 59                        3.384340e+09      3.343588e+10       110.108178
# 58                        3.614476e+09      3.254965e+10       111.407292
# 68                        3.959886e+09      3.177532e+10       118.320755
# 57                        4.319606e+09      3.014712e+10       147.244071
# 47                        4.732553e+09      3.171473e+10       148.805188
# 56                        5.098198e+09      3.134243e+10       153.402875
# 55                        4.592590e+09      3.156328e+10       155.619124
# 54                        5.144853e+09      2.692685e+10       160.471046
# 53                        5.743584e+09      2.197351e+10       157.527001
# 52                        5.811344e+09      2.736662e+10       152.294729
# 51                        5.844576e+09      2.528293e+10       148.625339
# 50                        5.548913e+09      2.087987e+10       147.845001
# 49                        5.700633e+09      1.934695e+10       142.092103
# 48                        5.747268e+09      1.769115e+10       140.023488
# 46                        5.889102e+09      1.826975e+10       136.889648

# %%
indicators_and_emissions_df.describe()
# Out:
#               year     pop_total  renewable_energy_consumption_pct  \
# count  3818.000000  3.818000e+03                       3818.000000
# mean   2011.000000  4.175823e+07                         28.497669
# std       6.634118  1.468786e+08                         28.742809
# min    2000.000000  1.764800e+04                          0.000000
# 25%    2005.000000  2.518963e+06                          4.700000
# 50%    2011.000000  9.201390e+06                         17.750000
# 75%    2017.000000  3.042670e+07                         46.900000
# max    2022.000000  1.425423e+09                         98.300000
#
#        forest_area_pct  gdp_2015_usd  imports_2015_usd  \
# count      3818.000000  3.818000e+03      3.818000e+03
# mean         30.523026  4.061426e+11      1.174562e+11
# std          23.407427  1.615210e+12      2.945360e+11
# min           0.000000  1.324972e+08      1.000002e+08
# 25%          11.000806  9.754041e+09      5.515070e+09
# 50%          28.673066  4.157595e+10      1.847410e+10
# 75%          46.460675  2.107496e+11      8.808246e+10
# max          95.577213  2.144339e+13      3.542496e+12
#
#        industry_value_added_2015_usd  manufacturing_value_added_2015_usd  \
# count                   3.818000e+03                        3.818000e+03
# mean                    1.093710e+11                        7.097559e+10
# std                     4.189506e+11                        3.091249e+11
# min                     9.434428e+06                        1.685068e+06
# 25%                     2.327919e+09                        9.057520e+08
# 50%                     1.112190e+10                        4.967951e+09
# 75%                     6.492572e+10                        3.636720e+10
# max                     6.430542e+12                        3.202510e+12
#
#        exports_2015_usd  total_emissions
# count      3.818000e+03      3818.000000
# mean       1.198367e+11       263.966266
# std        2.904175e+11       991.093662
# min        8.775953e+06         0.010029
# 25%        4.164145e+09        10.790480
# 50%        1.752229e+10        50.996469
# 75%        9.229121e+10       153.479223
# max        2.456083e+12     14511.221700

# %%
indicators_and_emissions_df.iso_alpha_3.unique().shape
# Out:
# (166,)

# %% [markdown]
# ## Add Lags

# %%
# Make sure the df is sorted by iso_alpha_3 and year
indicators_and_emissions_df_sorted = indicators_and_emissions_df.sort_values(by=["iso_alpha_3", "year"]).reset_index(drop=True)

# %%
indicators_and_emissions_df_sorted
# Out:
#      iso_alpha_3         income_group                       region  year  \
# 0            ABW          High income    Latin America & Caribbean  2000
# 1            ABW          High income    Latin America & Caribbean  2001
# 2            ABW          High income    Latin America & Caribbean  2002
# 3            ABW          High income    Latin America & Caribbean  2003
# 4            ABW          High income    Latin America & Caribbean  2004
# ...          ...                  ...                          ...   ...
# 3813         ZWE  Lower middle income  Africa Eastern and Southern  2018
# 3814         ZWE  Lower middle income  Africa Eastern and Southern  2019
# 3815         ZWE  Lower middle income  Africa Eastern and Southern  2020
# 3816         ZWE  Lower middle income  Africa Eastern and Southern  2021
# 3817         ZWE  Lower middle income  Africa Eastern and Southern  2022
#
#        pop_total  renewable_energy_consumption_pct  forest_area_pct  \
# 0        90588.0                               0.2         2.333333
# 1        91439.0                               0.2         2.333333
# 2        92074.0                               0.2         2.333333
# 3        93128.0                               0.2         2.333333
# 4        95138.0                               0.2         2.333333
# ...          ...                               ...              ...
# 3813  15034452.0                              79.7        45.332093
# 3814  15271368.0                              81.0        45.213002
# 3815  15526888.0                              84.1        45.093912
# 3816  15797210.0                              82.4        44.974822
# 3817  16069056.0                              81.2        44.855732
#
#       gdp_2015_usd  imports_2015_usd  industry_value_added_2015_usd  \
# 0     2.735727e+09      2.162352e+09                   3.694397e+08
# 1     2.850135e+09      2.162352e+09                   3.694397e+08
# 2     2.823203e+09      2.162352e+09                   3.694397e+08
# 3     2.854554e+09      2.162352e+09                   3.694397e+08
# 4     3.062758e+09      2.162352e+09                   3.694397e+08
# ...            ...               ...                            ...
# 3813  2.201518e+10      6.564741e+09                   4.817033e+09
# 3814  2.062108e+10      7.111395e+09                   4.403386e+09
# 3815  1.900914e+10      3.975341e+09                   4.040349e+09
# 3816  2.061884e+10      6.419766e+09                   4.297867e+09
# 3817  2.188468e+10      9.888019e+09                   4.522625e+09
#
#       manufacturing_value_added_2015_usd  exports_2015_usd  total_emissions
# 0                           1.062285e+08      2.158564e+09         0.335765
# 1                           1.062285e+08      2.158564e+09         0.344135
# 2                           1.062285e+08      2.158564e+09         0.363222
# 3                           1.062285e+08      2.158564e+09         0.412246
# 4                           1.062285e+08      2.158564e+09         0.430187
# ...                                  ...               ...              ...
# 3813                        2.451550e+09      4.709413e+09        47.509033
# 3814                        2.186755e+09      5.363550e+09        46.442562
# 3815                        1.782311e+09      2.738132e+09        44.576343
# 3816                        1.803676e+09      4.026367e+09        45.759664
# 3817                        1.828083e+09      5.775071e+09        46.423948
#
# [3818 rows x 13 columns]

# %%
training_df_lags = fe.generate_lagged_features(indicators_and_emissions_df_sorted, ["gdp_2015_usd", 
                                                          "imports_2015_usd", 
                                                          "exports_2015_usd", 
                                                          "industry_value_added_2015_usd", 
                                                          "manufacturing_value_added_2015_usd",
                                                          "pop_total"], max_lag=1)

# %%
training_df_lags.head()
# Out:
#   iso_alpha_3 income_group                     region  year  pop_total  \
# 0         ABW  High income  Latin America & Caribbean  2000    90588.0
# 1         ABW  High income  Latin America & Caribbean  2001    91439.0
# 2         ABW  High income  Latin America & Caribbean  2002    92074.0
# 3         ABW  High income  Latin America & Caribbean  2003    93128.0
# 4         ABW  High income  Latin America & Caribbean  2004    95138.0
#
#    renewable_energy_consumption_pct  forest_area_pct  gdp_2015_usd  \
# 0                               0.2         2.333333  2.735727e+09
# 1                               0.2         2.333333  2.850135e+09
# 2                               0.2         2.333333  2.823203e+09
# 3                               0.2         2.333333  2.854554e+09
# 4                               0.2         2.333333  3.062758e+09
#
#    imports_2015_usd  industry_value_added_2015_usd  \
# 0      2.162352e+09                   3.694397e+08
# 1      2.162352e+09                   3.694397e+08
# 2      2.162352e+09                   3.694397e+08
# 3      2.162352e+09                   3.694397e+08
# 4      2.162352e+09                   3.694397e+08
#
#    manufacturing_value_added_2015_usd  exports_2015_usd  total_emissions  \
# 0                        1.062285e+08      2.158564e+09         0.335765
# 1                        1.062285e+08      2.158564e+09         0.344135
# 2                        1.062285e+08      2.158564e+09         0.363222
# 3                        1.062285e+08      2.158564e+09         0.412246
# 4                        1.062285e+08      2.158564e+09         0.430187
#
#    gdp_2015_usd_lag1  imports_2015_usd_lag1  exports_2015_usd_lag1  \
# 0                NaN                    NaN                    NaN
# 1       2.735727e+09           2.162352e+09           2.158564e+09
# 2       2.850135e+09           2.162352e+09           2.158564e+09
# 3       2.823203e+09           2.162352e+09           2.158564e+09
# 4       2.854554e+09           2.162352e+09           2.158564e+09
#
#    industry_value_added_2015_usd_lag1  \
# 0                                 NaN
# 1                        3.694397e+08
# 2                        3.694397e+08
# 3                        3.694397e+08
# 4                        3.694397e+08
#
#    manufacturing_value_added_2015_usd_lag1  pop_total_lag1
# 0                                      NaN             NaN
# 1                             1.062285e+08         90588.0
# 2                             1.062285e+08         91439.0
# 3                             1.062285e+08         92074.0
# 4                             1.062285e+08         93128.0

# %%
training_df_lags.dropna(inplace=True)

# %%
training_df_lags.head()
# Out:
#   iso_alpha_3 income_group                     region  year  pop_total  \
# 1         ABW  High income  Latin America & Caribbean  2001    91439.0
# 2         ABW  High income  Latin America & Caribbean  2002    92074.0
# 3         ABW  High income  Latin America & Caribbean  2003    93128.0
# 4         ABW  High income  Latin America & Caribbean  2004    95138.0
# 5         ABW  High income  Latin America & Caribbean  2005    97635.0
#
#    renewable_energy_consumption_pct  forest_area_pct  gdp_2015_usd  \
# 1                               0.2         2.333333  2.850135e+09
# 2                               0.2         2.333333  2.823203e+09
# 3                               0.2         2.333333  2.854554e+09
# 4                               0.2         2.333333  3.062758e+09
# 5                               0.2         2.333333  3.051023e+09
#
#    imports_2015_usd  industry_value_added_2015_usd  \
# 1      2.162352e+09                   3.694397e+08
# 2      2.162352e+09                   3.694397e+08
# 3      2.162352e+09                   3.694397e+08
# 4      2.162352e+09                   3.694397e+08
# 5      2.162352e+09                   3.694397e+08
#
#    manufacturing_value_added_2015_usd  exports_2015_usd  total_emissions  \
# 1                        1.062285e+08      2.158564e+09         0.344135
# 2                        1.062285e+08      2.158564e+09         0.363222
# 3                        1.062285e+08      2.158564e+09         0.412246
# 4                        1.062285e+08      2.158564e+09         0.430187
# 5                        1.062285e+08      2.158564e+09         0.462648
#
#    gdp_2015_usd_lag1  imports_2015_usd_lag1  exports_2015_usd_lag1  \
# 1       2.735727e+09           2.162352e+09           2.158564e+09
# 2       2.850135e+09           2.162352e+09           2.158564e+09
# 3       2.823203e+09           2.162352e+09           2.158564e+09
# 4       2.854554e+09           2.162352e+09           2.158564e+09
# 5       3.062758e+09           2.162352e+09           2.158564e+09
#
#    industry_value_added_2015_usd_lag1  \
# 1                        3.694397e+08
# 2                        3.694397e+08
# 3                        3.694397e+08
# 4                        3.694397e+08
# 5                        3.694397e+08
#
#    manufacturing_value_added_2015_usd_lag1  pop_total_lag1
# 1                             1.062285e+08         90588.0
# 2                             1.062285e+08         91439.0
# 3                             1.062285e+08         92074.0
# 4                             1.062285e+08         93128.0
# 5                             1.062285e+08         95138.0

# %%
training_df_lags.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3652 entries, 1 to 3817
# Data columns (total 19 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   iso_alpha_3                              3652 non-null   object
#  1   income_group                             3652 non-null   object
#  2   region                                   3652 non-null   object
#  3   year                                     3652 non-null   int64
#  4   pop_total                                3652 non-null   float64
#  5   renewable_energy_consumption_pct         3652 non-null   float64
#  6   forest_area_pct                          3652 non-null   float64
#  7   gdp_2015_usd                             3652 non-null   float64
#  8   imports_2015_usd                         3652 non-null   float64
#  9   industry_value_added_2015_usd            3652 non-null   float64
#  10  manufacturing_value_added_2015_usd       3652 non-null   float64
#  11  exports_2015_usd                         3652 non-null   float64
#  12  total_emissions                          3652 non-null   float64
#  13  gdp_2015_usd_lag1                        3652 non-null   float64
#  14  imports_2015_usd_lag1                    3652 non-null   float64
#  15  exports_2015_usd_lag1                    3652 non-null   float64
#  16  industry_value_added_2015_usd_lag1       3652 non-null   float64
#  17  manufacturing_value_added_2015_usd_lag1  3652 non-null   float64
#  18  pop_total_lag1                           3652 non-null   float64
# dtypes: float64(15), int64(1), object(3)
# memory usage: 570.6+ KB

# %%
training_df_lags[training_df_lags["iso_alpha_3"] == "AGO"].sort_values(by="year")
# Out:
#    iso_alpha_3         income_group                       region  year  \
# 47         AGO  Lower middle income  Africa Eastern and Southern  2001
# 48         AGO  Lower middle income  Africa Eastern and Southern  2002
# 49         AGO  Lower middle income  Africa Eastern and Southern  2003
# 50         AGO  Lower middle income  Africa Eastern and Southern  2004
# 51         AGO  Lower middle income  Africa Eastern and Southern  2005
# 52         AGO  Lower middle income  Africa Eastern and Southern  2006
# 53         AGO  Lower middle income  Africa Eastern and Southern  2007
# 54         AGO  Lower middle income  Africa Eastern and Southern  2008
# 55         AGO  Lower middle income  Africa Eastern and Southern  2009
# 56         AGO  Lower middle income  Africa Eastern and Southern  2010
# 57         AGO  Lower middle income  Africa Eastern and Southern  2011
# 58         AGO  Lower middle income  Africa Eastern and Southern  2012
# 59         AGO  Lower middle income  Africa Eastern and Southern  2013
# 60         AGO  Lower middle income  Africa Eastern and Southern  2014
# 61         AGO  Lower middle income  Africa Eastern and Southern  2015
# 62         AGO  Lower middle income  Africa Eastern and Southern  2016
# 63         AGO  Lower middle income  Africa Eastern and Southern  2017
# 64         AGO  Lower middle income  Africa Eastern and Southern  2018
# 65         AGO  Lower middle income  Africa Eastern and Southern  2019
# 66         AGO  Lower middle income  Africa Eastern and Southern  2020
# 67         AGO  Lower middle income  Africa Eastern and Southern  2021
# 68         AGO  Lower middle income  Africa Eastern and Southern  2022
#
#      pop_total  renewable_energy_consumption_pct  forest_area_pct  \
# 47  16747208.0                              72.8        61.886219
# 48  17327699.0                              70.8        61.440995
# 49  17943712.0                              65.6        60.995770
# 50  18600423.0                              62.3        60.550546
# 51  19291161.0                              68.9        60.105322
# 52  20015279.0                              62.6        59.660098
# 53  20778561.0                              58.9        59.214874
# 54  21578655.0                              55.4        58.769649
# 55  22414773.0                              53.0        58.324425
# 56  23294825.0                              53.1        57.879201
# 57  24218352.0                              51.7        57.433976
# 58  25177394.0                              49.0        56.988751
# 59  26165620.0                              46.8        56.543526
# 60  27160769.0                              47.5        56.098301
# 61  28157798.0                              47.1        55.653076
# 62  29183070.0                              48.1        55.207845
# 63  30234839.0                              52.5        54.762629
# 64  31297155.0                              52.5        54.317406
# 65  32375632.0                              51.0        53.872175
# 66  33451132.0                              60.1        53.426951
# 67  34532429.0                              52.9        52.981722
# 68  35635029.0                              49.0        52.536497
#
#     gdp_2015_usd  imports_2015_usd  industry_value_added_2015_usd  \
# 47  3.262116e+10      2.298069e+10                   1.621840e+10
# 48  3.707907e+10      2.298069e+10                   1.621840e+10
# 49  3.818773e+10      2.520752e+10                   1.620435e+10
# 50  4.236929e+10      2.700481e+10                   1.860275e+10
# 51  4.873739e+10      3.023189e+10                   2.241556e+10
# 52  5.436656e+10      3.215161e+10                   2.537292e+10
# 53  6.198332e+10      3.459513e+10                   3.039648e+10
# 54  6.890685e+10      4.088107e+10                   3.330444e+10
# 55  6.949945e+10      4.068712e+10                   3.200557e+10
# 56  7.255630e+10      3.591116e+10                   3.197610e+10
# 57  7.507549e+10      3.984345e+10                   3.128685e+10
# 58  8.148852e+10      3.980781e+10                   3.457634e+10
# 59  8.552596e+10      4.155085e+10                   3.560264e+10
# 60  8.965050e+10      3.940746e+10                   3.504457e+10
# 61  9.049642e+10      2.998501e+10                   3.794795e+10
# 62  8.816157e+10      2.256705e+10                   3.770875e+10
# 63  8.803178e+10      2.510203e+10                   3.650684e+10
# 64  8.687297e+10      2.109186e+10                   3.423869e+10
# 65  8.626288e+10      1.580866e+10                   3.304787e+10
# 66  8.139919e+10      1.237904e+10                   2.959055e+10
# 67  8.237534e+10      1.190661e+10                   2.712328e+10
# 68  8.488345e+10      1.501539e+10                   2.760259e+10
#
#     manufacturing_value_added_2015_usd  exports_2015_usd  total_emissions  \
# 47                        2.255448e+09      1.653568e+10       109.364994
# 48                        2.255448e+09      1.653568e+10       108.114862
# 49                        2.376152e+09      1.632072e+10       108.366595
# 50                        2.770014e+09      1.845710e+10       114.489712
# 51                        2.939686e+09      2.268931e+10       113.596505
# 52                        3.132186e+09      2.593161e+10       106.468040
# 53                        3.195348e+09      3.022589e+10       105.871055
# 54                        3.384340e+09      3.343588e+10       110.108178
# 55                        3.614476e+09      3.254965e+10       111.407292
# 56                        3.959886e+09      3.177532e+10       118.320755
# 57                        4.319606e+09      3.014712e+10       147.244071
# 58                        4.732553e+09      3.171473e+10       148.805188
# 59                        5.098198e+09      3.134243e+10       153.402875
# 60                        4.592590e+09      3.156328e+10       155.619124
# 61                        5.144853e+09      2.692685e+10       160.471046
# 62                        5.743584e+09      2.197351e+10       157.527001
# 63                        5.811344e+09      2.736662e+10       152.294729
# 64                        5.844576e+09      2.528293e+10       148.625339
# 65                        5.548913e+09      2.087987e+10       147.845001
# 66                        5.700633e+09      1.934695e+10       142.092103
# 67                        5.747268e+09      1.769115e+10       140.023488
# 68                        5.889102e+09      1.826975e+10       136.889648
#
#     gdp_2015_usd_lag1  imports_2015_usd_lag1  exports_2015_usd_lag1  \
# 47       3.130450e+10           2.298069e+10           1.653568e+10
# 48       3.262116e+10           2.298069e+10           1.653568e+10
# 49       3.707907e+10           2.298069e+10           1.653568e+10
# 50       3.818773e+10           2.520752e+10           1.632072e+10
# 51       4.236929e+10           2.700481e+10           1.845710e+10
# 52       4.873739e+10           3.023189e+10           2.268931e+10
# 53       5.436656e+10           3.215161e+10           2.593161e+10
# 54       6.198332e+10           3.459513e+10           3.022589e+10
# 55       6.890685e+10           4.088107e+10           3.343588e+10
# 56       6.949945e+10           4.068712e+10           3.254965e+10
# 57       7.255630e+10           3.591116e+10           3.177532e+10
# 58       7.507549e+10           3.984345e+10           3.014712e+10
# 59       8.148852e+10           3.980781e+10           3.171473e+10
# 60       8.552596e+10           4.155085e+10           3.134243e+10
# 61       8.965050e+10           3.940746e+10           3.156328e+10
# 62       9.049642e+10           2.998501e+10           2.692685e+10
# 63       8.816157e+10           2.256705e+10           2.197351e+10
# 64       8.803178e+10           2.510203e+10           2.736662e+10
# 65       8.687297e+10           2.109186e+10           2.528293e+10
# 66       8.626288e+10           1.580866e+10           2.087987e+10
# 67       8.139919e+10           1.237904e+10           1.934695e+10
# 68       8.237534e+10           1.190661e+10           1.769115e+10
#
#     industry_value_added_2015_usd_lag1  \
# 47                        1.621840e+10
# 48                        1.621840e+10
# 49                        1.621840e+10
# 50                        1.620435e+10
# 51                        1.860275e+10
# 52                        2.241556e+10
# 53                        2.537292e+10
# 54                        3.039648e+10
# 55                        3.330444e+10
# 56                        3.200557e+10
# 57                        3.197610e+10
# 58                        3.128685e+10
# 59                        3.457634e+10
# 60                        3.560264e+10
# 61                        3.504457e+10
# 62                        3.794795e+10
# 63                        3.770875e+10
# 64                        3.650684e+10
# 65                        3.423869e+10
# 66                        3.304787e+10
# 67                        2.959055e+10
# 68                        2.712328e+10
#
#     manufacturing_value_added_2015_usd_lag1  pop_total_lag1
# 47                             2.255448e+09      16194869.0
# 48                             2.255448e+09      16747208.0
# 49                             2.255448e+09      17327699.0
# 50                             2.376152e+09      17943712.0
# 51                             2.770014e+09      18600423.0
# 52                             2.939686e+09      19291161.0
# 53                             3.132186e+09      20015279.0
# 54                             3.195348e+09      20778561.0
# 55                             3.384340e+09      21578655.0
# 56                             3.614476e+09      22414773.0
# 57                             3.959886e+09      23294825.0
# 58                             4.319606e+09      24218352.0
# 59                             4.732553e+09      25177394.0
# 60                             5.098198e+09      26165620.0
# 61                             4.592590e+09      27160769.0
# 62                             5.144853e+09      28157798.0
# 63                             5.743584e+09      29183070.0
# 64                             5.811344e+09      30234839.0
# 65                             5.844576e+09      31297155.0
# 66                             5.548913e+09      32375632.0
# 67                             5.700633e+09      33451132.0
# 68                             5.747268e+09      34532429.0

# %% [markdown]
# ## EDA 1

# %%
eda_utils.plot_numeric_fields_distributions(training_df_lags)

# %%
eda_utils.plot_correlation_matrix(training_df_lags, figsize=(12,8))

# %% [markdown]
# ## Feature Engineering for Numeric Features

# %%
# Get the numeric columns
numeric_cols = training_df_lags.select_dtypes(include=["float64", "int64"]).columns.tolist()
numeric_cols_to_drop = ["year"]
numeric_cols = [col for col in numeric_cols if col not in numeric_cols_to_drop]
numeric_cols
# Out:
# ['pop_total',
#  'renewable_energy_consumption_pct',
#  'forest_area_pct',
#  'gdp_2015_usd',
#  'imports_2015_usd',
#  'industry_value_added_2015_usd',
#  'manufacturing_value_added_2015_usd',
#  'exports_2015_usd',
#  'total_emissions',
#  'gdp_2015_usd_lag1',
#  'imports_2015_usd_lag1',
#  'exports_2015_usd_lag1',
#  'industry_value_added_2015_usd_lag1',
#  'manufacturing_value_added_2015_usd_lag1',
#  'pop_total_lag1']

# %%
# Log transform the numeric columns with high skewness
training_df_log_transformed = fe.log_transform_high_skew(training_df_lags, numeric_cols, skew_threshold=1.0)
training_df_log_transformed.head()
# Out:
# Columns dropped due to high skewness: ['pop_total', 'gdp_2015_usd', 'imports_2015_usd', 'industry_value_added_2015_usd', 'manufacturing_value_added_2015_usd', 'exports_2015_usd', 'total_emissions', 'gdp_2015_usd_lag1', 'imports_2015_usd_lag1', 'exports_2015_usd_lag1', 'industry_value_added_2015_usd_lag1', 'manufacturing_value_added_2015_usd_lag1', 'pop_total_lag1']
#   iso_alpha_3 income_group                     region  year  \
# 1         ABW  High income  Latin America & Caribbean  2001
# 2         ABW  High income  Latin America & Caribbean  2002
# 3         ABW  High income  Latin America & Caribbean  2003
# 4         ABW  High income  Latin America & Caribbean  2004
# 5         ABW  High income  Latin America & Caribbean  2005
#
#    renewable_energy_consumption_pct  forest_area_pct  log_pop_total  \
# 1                               0.2         2.333333      11.423438
# 2                               0.2         2.333333      11.430359
# 3                               0.2         2.333333      11.441741
# 4                               0.2         2.333333      11.463094
# 5                               0.2         2.333333      11.489002
#
#    log_gdp_2015_usd  log_imports_2015_usd  log_industry_value_added_2015_usd  \
# 1         21.770632             21.494462                          19.727498
# 2         21.761138             21.494462                          19.727498
# 3         21.772182             21.494462                          19.727498
# 4         21.842582             21.494462                          19.727498
# 5         21.838743             21.494462                          19.727498
#
#    log_manufacturing_value_added_2015_usd  log_exports_2015_usd  \
# 1                               18.481103             21.492709
# 2                               18.481103             21.492709
# 3                               18.481103             21.492709
# 4                               18.481103             21.492709
# 5                               18.481103             21.492709
#
#    log_total_emissions  log_gdp_2015_usd_lag1  log_imports_2015_usd_lag1  \
# 1             0.295751              21.729663                  21.494462
# 2             0.309851              21.770632                  21.494462
# 3             0.345181              21.761138                  21.494462
# 4             0.357805              21.772182                  21.494462
# 5             0.380248              21.842582                  21.494462
#
#    log_exports_2015_usd_lag1  log_industry_value_added_2015_usd_lag1  \
# 1                  21.492709                               19.727498
# 2                  21.492709                               19.727498
# 3                  21.492709                               19.727498
# 4                  21.492709                               19.727498
# 5                  21.492709                               19.727498
#
#    log_manufacturing_value_added_2015_usd_lag1  log_pop_total_lag1
# 1                                    18.481103           11.414088
# 2                                    18.481103           11.423438
# 3                                    18.481103           11.430359
# 4                                    18.481103           11.441741
# 5                                    18.481103           11.463094

# %%
training_df_log_transformed.describe()
# Out:
#               year  renewable_energy_consumption_pct  forest_area_pct  \
# count  3652.000000                       3652.000000      3652.000000
# mean   2011.500000                         28.414047        30.505160
# std       6.345158                         28.636170        23.389084
# min    2001.000000                          0.000000         0.000000
# 25%    2006.000000                          4.800000        10.995311
# 50%    2011.500000                         17.700000        28.694570
# 75%    2017.000000                         46.700000        46.405971
# max    2022.000000                         98.300000        95.551663
#
#        log_pop_total  log_gdp_2015_usd  log_imports_2015_usd  \
# count    3652.000000       3652.000000           3652.000000
# mean       15.742322         24.549953             23.830522
# std         2.170131          2.138411              1.938449
# min         9.778434         18.702072             18.420683
# 25%        14.757104         23.026356             22.462717
# 50%        16.038282         24.473709             23.643119
# 75%        17.238215         26.091825             25.236930
# max        21.077735         30.696437             28.895853
#
#        log_industry_value_added_2015_usd  \
# count                        3652.000000
# mean                           23.135900
# std                             2.381468
# min                            16.059876
# 25%                            21.572375
# 50%                            23.141496
# 75%                            24.904157
# max                            29.492080
#
#        log_manufacturing_value_added_2015_usd  log_exports_2015_usd  \
# count                             3652.000000           3652.000000
# mean                                22.263473             23.676156
# std                                  2.662728              2.142871
# min                                 14.337317             15.987526
# 25%                                 20.633662             22.173449
# 50%                                 22.334882             23.590076
# 75%                                 24.343946             25.248215
# max                                 28.794956             28.529589
#
#        log_total_emissions  log_gdp_2015_usd_lag1  log_imports_2015_usd_lag1  \
# count          3652.000000            3652.000000                3652.000000
# mean              3.791916              24.518541                  23.794898
# std               1.930787               2.139478                   1.939736
# min               0.009979              18.702072                  18.420683
# 25%               2.477529              22.985895                  22.407955
# 50%               3.952569              24.435525                  23.634821
# 75%               5.051764              26.071027                  25.174840
# max               9.582746              30.671624                  28.813416
#
#        log_exports_2015_usd_lag1  log_industry_value_added_2015_usd_lag1  \
# count                3652.000000                             3652.000000
# mean                   23.645994                               23.110070
# std                     2.142659                                2.382641
# min                    15.987526                               16.059876
# 25%                    22.122007                               21.560559
# 50%                    23.554063                               23.125899
# 75%                    25.248215                               24.884484
# max                    28.529589                               29.466047
#
#        log_manufacturing_value_added_2015_usd_lag1  log_pop_total_lag1
# count                                  3652.000000         3652.000000
# mean                                     22.240833           15.728891
# std                                       2.659156            2.170115
# min                                      14.337317            9.778434
# 25%                                      20.624276           14.734655
# 50%                                      22.326273           16.021940
# 75%                                      24.305520           17.218693
# max                                      28.794956           21.069833

# %%
training_df_log_transformed.isna().sum()
# Out:
# iso_alpha_3                                    0
# income_group                                   0
# region                                         0
# year                                           0
# renewable_energy_consumption_pct               0
# forest_area_pct                                0
# log_pop_total                                  0
# log_gdp_2015_usd                               0
# log_imports_2015_usd                           0
# log_industry_value_added_2015_usd              0
# log_manufacturing_value_added_2015_usd         0
# log_exports_2015_usd                           0
# log_total_emissions                            0
# log_gdp_2015_usd_lag1                          0
# log_imports_2015_usd_lag1                      0
# log_exports_2015_usd_lag1                      0
# log_industry_value_added_2015_usd_lag1         0
# log_manufacturing_value_added_2015_usd_lag1    0
# log_pop_total_lag1                             0
# dtype: int64

# %%
training_df_lags.isna().sum()
# Out:
# iso_alpha_3                                0
# income_group                               0
# region                                     0
# year                                       0
# pop_total                                  0
# renewable_energy_consumption_pct           0
# forest_area_pct                            0
# gdp_2015_usd                               0
# imports_2015_usd                           0
# industry_value_added_2015_usd              0
# manufacturing_value_added_2015_usd         0
# exports_2015_usd                           0
# total_emissions                            0
# gdp_2015_usd_lag1                          0
# imports_2015_usd_lag1                      0
# exports_2015_usd_lag1                      0
# industry_value_added_2015_usd_lag1         0
# manufacturing_value_added_2015_usd_lag1    0
# pop_total_lag1                             0
# dtype: int64

# %% [markdown]
# ## EDA log transformed data

# %%
eda_utils.plot_correlation_matrix(training_df_log_transformed, figsize=(15,10))

# %%
eda_utils.plot_numeric_fields_distributions(training_df_log_transformed)

# %%
eda_utils.find_outlier_columns(training_df_log_transformed)
# Out:
# {'log_exports_2015_usd': 0.5750273822562979,
#  'log_exports_2015_usd_lag1': 0.5750273822562979}

# %% [markdown]
# ## ML

# %%
training_df_log_transformed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3652 entries, 1 to 3817
# Data columns (total 19 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   iso_alpha_3                                  3652 non-null   object
#  1   income_group                                 3652 non-null   object
#  2   region                                       3652 non-null   object
#  3   year                                         3652 non-null   int64
#  4   renewable_energy_consumption_pct             3652 non-null   float64
#  5   forest_area_pct                              3652 non-null   float64
#  6   log_pop_total                                3652 non-null   float64
#  7   log_gdp_2015_usd                             3652 non-null   float64
#  8   log_imports_2015_usd                         3652 non-null   float64
#  9   log_industry_value_added_2015_usd            3652 non-null   float64
#  10  log_manufacturing_value_added_2015_usd       3652 non-null   float64
#  11  log_exports_2015_usd                         3652 non-null   float64
#  12  log_total_emissions                          3652 non-null   float64
#  13  log_gdp_2015_usd_lag1                        3652 non-null   float64
#  14  log_imports_2015_usd_lag1                    3652 non-null   float64
#  15  log_exports_2015_usd_lag1                    3652 non-null   float64
#  16  log_industry_value_added_2015_usd_lag1       3652 non-null   float64
#  17  log_manufacturing_value_added_2015_usd_lag1  3652 non-null   float64
#  18  log_pop_total_lag1                           3652 non-null   float64
# dtypes: float64(15), int64(1), object(3)
# memory usage: 570.6+ KB

# %%
# Make sure the df is sorted by iso_alpha_3 and year
training_df_log_transformed = training_df_log_transformed.sort_values(by=["iso_alpha_3", "year"]).reset_index(drop=True)

# %%
reg_a = RegressionAnalysis(training_df_log_transformed,
                           target_col="log_total_emissions",
                           group_col="iso_alpha_3",
                           year_col="year",
                           scaler_type="minmax",
                           use_group_feature=True
                           )

reg_a.run_all(plot_importances=True, importances_model='xgboost')
# Out:
# Cross-Validation Results:
# ------------------------------------------------------------------------------------------------------------------------
# Model              Group MAE    (std)     Time MAE    (std)     Group R2    (std)      Time R2    (std)
# ------------------------------------------------------------------------------------------------------------------------
# RandomForest          0.5538   0.0607       0.6224   0.0430       0.8336   0.0313       0.7805   0.0357
# XGBoost               0.5237   0.0314       0.6423   0.0559       0.8633   0.0217       0.7871   0.0273
# ElasticNet            0.5610   0.0372       0.5825   0.0737       0.8510   0.0451       0.8231   0.0730
# Median                1.5254   0.1554       1.5295   0.1598      -0.0163   0.0178      -0.0417   0.0821
#
# Evaluation Results:
# --------------------------------------------------------------------------------
# Model            Train MAE   Test MAE   Train R2    Test R2
# --------------------------------------------------------------------------------
# RandomForest        0.0215     0.1625     0.9996     0.9825
# XGBoost             0.0543     0.1499     0.9985     0.9877
# ElasticNet          0.1210     0.1693     0.9911     0.9807
# Median              1.5217     1.5057    -0.0083    -0.0016

# %%
reg_b = RegressionAnalysis(training_df_log_transformed,
                           target_col="log_total_emissions",
                           group_col="iso_alpha_3",
                           year_col="year",
                           scaler_type="robust",
                           use_group_feature=True
                           )

reg_b.run_all(plot_importances=True, importances_model='xgboost')
# Out:
# Cross-Validation Results:
# ------------------------------------------------------------------------------------------------------------------------
# Model              Group MAE    (std)     Time MAE    (std)     Group R2    (std)      Time R2    (std)
# ------------------------------------------------------------------------------------------------------------------------
# RandomForest          0.5537   0.0607       0.6224   0.0430       0.8337   0.0314       0.7805   0.0358
# XGBoost               0.5237   0.0314       0.6423   0.0559       0.8633   0.0217       0.7871   0.0273
# ElasticNet            0.5401   0.0370       0.6070   0.0710       0.8603   0.0459       0.8241   0.0877
# Median                1.5254   0.1554       1.5295   0.1598      -0.0163   0.0178      -0.0417   0.0821
#
# Evaluation Results:
# --------------------------------------------------------------------------------
# Model            Train MAE   Test MAE   Train R2    Test R2
# --------------------------------------------------------------------------------
# RandomForest        0.0216     0.1625     0.9996     0.9825
# XGBoost             0.0543     0.1499     0.9985     0.9877
# ElasticNet          0.3455     0.3385     0.9506     0.9506
# Median              1.5217     1.5057    -0.0083    -0.0016

# %%
reg_c = RegressionAnalysis(training_df_log_transformed,
                           target_col="log_total_emissions",
                           group_col="iso_alpha_3",
                           year_col="year",
                           scaler_type="minmax",
                           use_group_feature=False,
                           )

reg_c.run_all(plot_importances=True, importances_model='xgboost')
# Out:
# Cross-Validation Results:
# ------------------------------------------------------------------------------------------------------------------------
# Model              Group MAE    (std)     Time MAE    (std)     Group R2    (std)      Time R2    (std)
# ------------------------------------------------------------------------------------------------------------------------
# RandomForest          0.5648   0.0649       0.6212   0.0401       0.8348   0.0290       0.7875   0.0362
# XGBoost               0.5393   0.0460       0.6538   0.0394       0.8535   0.0200       0.7876   0.0190
# ElasticNet            0.5582   0.0353       0.6213   0.0464       0.8580   0.0386       0.8194   0.0600
# Median                1.5254   0.1554       1.5295   0.1598      -0.0163   0.0178      -0.0417   0.0821
#
# Evaluation Results:
# --------------------------------------------------------------------------------
# Model            Train MAE   Test MAE   Train R2    Test R2
# --------------------------------------------------------------------------------
# RandomForest        0.0253     0.1771     0.9994     0.9798
# XGBoost             0.0262     0.1628     0.9996     0.9837
# ElasticNet          0.4834     0.4736     0.8960     0.9036
# Median              1.5217     1.5057    -0.0083    -0.0016

# %%
xgb_params = dict(
    n_estimators=300,      # Enough trees, not excessive for this size
    max_depth=4,           # Controls overfitting, 4–6 is common
    learning_rate=0.07,    # Slower learning, safer default than 0.1
    subsample=0.8,         # Row sampling for robustness
    colsample_bytree=0.8,  # Feature sampling per tree for robustness
    reg_alpha=0.2,         # L1 regularization, good for tabular data
    reg_lambda=1.0,        # L2 regularization (default 1.0, safe)
    random_state=42,       # For reproducibility
    n_jobs=-1,             # Use all cores
    verbosity=0
)

reg_d = RegressionAnalysis(training_df_log_transformed,
                            target_col="log_total_emissions",
                            group_col="iso_alpha_3",
                            year_col="year",
                            scaler_type="minmax",
                            use_group_feature=False,
                            xgb_params=xgb_params
                            )

reg_d.run_all(plot_importances=True, importances_model='xgboost')
# Out:
# Cross-Validation Results:
# ------------------------------------------------------------------------------------------------------------------------
# Model              Group MAE    (std)     Time MAE    (std)     Group R2    (std)      Time R2    (std)
# ------------------------------------------------------------------------------------------------------------------------
# RandomForest          0.5648   0.0649       0.6212   0.0401       0.8348   0.0290       0.7875   0.0362
# XGBoost               0.5319   0.0190       0.6311   0.0549       0.8645   0.0282       0.7964   0.0430
# ElasticNet            0.5582   0.0353       0.6213   0.0464       0.8580   0.0386       0.8194   0.0600
# Median                1.5254   0.1554       1.5295   0.1598      -0.0163   0.0178      -0.0417   0.0821
#
# Evaluation Results:
# --------------------------------------------------------------------------------
# Model            Train MAE   Test MAE   Train R2    Test R2
# --------------------------------------------------------------------------------
# RandomForest        0.0253     0.1771     0.9994     0.9798
# XGBoost             0.0786     0.1911     0.9968     0.9812
# ElasticNet          0.4834     0.4736     0.8960     0.9036
# Median              1.5217     1.5057    -0.0083    -0.0016

# %% [markdown]
# ## Create projections

# %%
from utils.ml_utils_v2 import EnsembleProjections
ep = EnsembleProjections()

# %%
training_df_log_transformed.head()
# Out:
#   iso_alpha_3 income_group                     region  year  \
# 0         ABW  High income  Latin America & Caribbean  2001
# 1         ABW  High income  Latin America & Caribbean  2002
# 2         ABW  High income  Latin America & Caribbean  2003
# 3         ABW  High income  Latin America & Caribbean  2004
# 4         ABW  High income  Latin America & Caribbean  2005
#
#    renewable_energy_consumption_pct  forest_area_pct  log_pop_total  \
# 0                               0.2         2.333333      11.423438
# 1                               0.2         2.333333      11.430359
# 2                               0.2         2.333333      11.441741
# 3                               0.2         2.333333      11.463094
# 4                               0.2         2.333333      11.489002
#
#    log_gdp_2015_usd  log_imports_2015_usd  log_industry_value_added_2015_usd  \
# 0         21.770632             21.494462                          19.727498
# 1         21.761138             21.494462                          19.727498
# 2         21.772182             21.494462                          19.727498
# 3         21.842582             21.494462                          19.727498
# 4         21.838743             21.494462                          19.727498
#
#    log_manufacturing_value_added_2015_usd  log_exports_2015_usd  \
# 0                               18.481103             21.492709
# 1                               18.481103             21.492709
# 2                               18.481103             21.492709
# 3                               18.481103             21.492709
# 4                               18.481103             21.492709
#
#    log_total_emissions  log_gdp_2015_usd_lag1  log_imports_2015_usd_lag1  \
# 0             0.295751              21.729663                  21.494462
# 1             0.309851              21.770632                  21.494462
# 2             0.345181              21.761138                  21.494462
# 3             0.357805              21.772182                  21.494462
# 4             0.380248              21.842582                  21.494462
#
#    log_exports_2015_usd_lag1  log_industry_value_added_2015_usd_lag1  \
# 0                  21.492709                               19.727498
# 1                  21.492709                               19.727498
# 2                  21.492709                               19.727498
# 3                  21.492709                               19.727498
# 4                  21.492709                               19.727498
#
#    log_manufacturing_value_added_2015_usd_lag1  log_pop_total_lag1
# 0                                    18.481103           11.414088
# 1                                    18.481103           11.423438
# 2                                    18.481103           11.430359
# 3                                    18.481103           11.441741
# 4                                    18.481103           11.463094

# %%
numeric_cols = training_df_log_transformed.select_dtypes(include=["float64", "int64"]).columns.tolist()
numeric_cols_to_drop = ["year", "log_total_emissions"]
numeric_cols = [col for col in numeric_cols if col not in numeric_cols_to_drop]
numeric_cols
# Out:
# ['renewable_energy_consumption_pct',
#  'forest_area_pct',
#  'log_pop_total',
#  'log_gdp_2015_usd',
#  'log_imports_2015_usd',
#  'log_industry_value_added_2015_usd',
#  'log_manufacturing_value_added_2015_usd',
#  'log_exports_2015_usd',
#  'log_gdp_2015_usd_lag1',
#  'log_imports_2015_usd_lag1',
#  'log_exports_2015_usd_lag1',
#  'log_industry_value_added_2015_usd_lag1',
#  'log_manufacturing_value_added_2015_usd_lag1',
#  'log_pop_total_lag1']

# %%
# ensemble_ets_df = ep.generate_ensemble_ts_lhs(
#     df=training_df_log_transformed,
#     feature_cols=feature_cols,
#     start_year=2022,
#     end_year=2030,
#     n_scenarios=10,
#     method="ets",            # or "arima"
#     arima_order=(1,1,1),     # only used if method="arima"
#     random_state=42
# )

ensemble_arima_df = ep.generate_ensemble_ts_lhs(
    df=training_df_log_transformed,
    feature_cols=numeric_cols,
    start_year=2022,
    end_year=2030,
    n_scenarios=10,
    method="arima",          # or "ets"
    arima_order=(1,1,1),     # only used if method="arima"
    random_state=42
)

# %%
# ensemble_ets_df.head()

# %%
# ensemble_ets_df.info()

# %%
training_df_log_transformed.head()
# Out:
#   iso_alpha_3 income_group                     region  year  \
# 0         ABW  High income  Latin America & Caribbean  2001
# 1         ABW  High income  Latin America & Caribbean  2002
# 2         ABW  High income  Latin America & Caribbean  2003
# 3         ABW  High income  Latin America & Caribbean  2004
# 4         ABW  High income  Latin America & Caribbean  2005
#
#    renewable_energy_consumption_pct  forest_area_pct  log_pop_total  \
# 0                               0.2         2.333333      11.423438
# 1                               0.2         2.333333      11.430359
# 2                               0.2         2.333333      11.441741
# 3                               0.2         2.333333      11.463094
# 4                               0.2         2.333333      11.489002
#
#    log_gdp_2015_usd  log_imports_2015_usd  log_industry_value_added_2015_usd  \
# 0         21.770632             21.494462                          19.727498
# 1         21.761138             21.494462                          19.727498
# 2         21.772182             21.494462                          19.727498
# 3         21.842582             21.494462                          19.727498
# 4         21.838743             21.494462                          19.727498
#
#    log_manufacturing_value_added_2015_usd  log_exports_2015_usd  \
# 0                               18.481103             21.492709
# 1                               18.481103             21.492709
# 2                               18.481103             21.492709
# 3                               18.481103             21.492709
# 4                               18.481103             21.492709
#
#    log_total_emissions  log_gdp_2015_usd_lag1  log_imports_2015_usd_lag1  \
# 0             0.295751              21.729663                  21.494462
# 1             0.309851              21.770632                  21.494462
# 2             0.345181              21.761138                  21.494462
# 3             0.357805              21.772182                  21.494462
# 4             0.380248              21.842582                  21.494462
#
#    log_exports_2015_usd_lag1  log_industry_value_added_2015_usd_lag1  \
# 0                  21.492709                               19.727498
# 1                  21.492709                               19.727498
# 2                  21.492709                               19.727498
# 3                  21.492709                               19.727498
# 4                  21.492709                               19.727498
#
#    log_manufacturing_value_added_2015_usd_lag1  log_pop_total_lag1
# 0                                    18.481103           11.414088
# 1                                    18.481103           11.423438
# 2                                    18.481103           11.430359
# 3                                    18.481103           11.441741
# 4                                    18.481103           11.463094

# %%
# ep.plot_ensemble_time_series(
#     df=ensemble_ets_df, 
#     iso_alpha_3="AUS",
#     column="log_industry_value_added_2015_usd",
#     hist_df=training_df_log_transformed)

# %%
# Make sure ensemble_arima_df is sorted by iso_alpha_3 and year
ensemble_arima_df = ensemble_arima_df.sort_values(by=["iso_alpha_3", "year"]).reset_index(drop=True)
ensemble_arima_df.head()
# Out:
#   iso_alpha_3 future_id  year  renewable_energy_consumption_pct  \
# 0         ABW  id_ABW_1  2022                          7.762582
# 1         ABW  id_ABW_2  2022                          8.599340
# 2         ABW  id_ABW_3  2022                          8.743618
# 3         ABW  id_ABW_4  2022                          8.405104
# 4         ABW  id_ABW_5  2022                          9.454867
#
#    forest_area_pct  log_pop_total  log_gdp_2015_usd  log_imports_2015_usd  \
# 0         2.333333      11.582989         21.674358             21.494463
# 1         2.333333      11.582025         21.819419             21.494462
# 2         2.333331      11.581838         21.816428             21.494462
# 3         2.333333      11.574549         21.869997             21.494461
# 4         2.333334      11.580662         21.923628             21.494462
#
#    log_industry_value_added_2015_usd  log_manufacturing_value_added_2015_usd  \
# 0                          19.727497                               18.481103
# 1                          19.727497                               18.481104
# 2                          19.727497                               18.481103
# 3                          19.727496                               18.481102
# 4                          19.727499                               18.481103
#
#    log_exports_2015_usd  log_gdp_2015_usd_lag1  log_imports_2015_usd_lag1  \
# 0             21.492709              21.766008                  21.494462
# 1             21.492709              21.871418                  21.494463
# 2             21.492711              21.839371                  21.494462
# 3             21.492709              21.801312                  21.494464
# 4             21.492709              21.697756                  21.494463
#
#    log_exports_2015_usd_lag1  log_industry_value_added_2015_usd_lag1  \
# 0                  21.492711                               19.727497
# 1                  21.492709                               19.727500
# 2                  21.492710                               19.727500
# 3                  21.492708                               19.727498
# 4                  21.492710                               19.727497
#
#    log_manufacturing_value_added_2015_usd_lag1  log_pop_total_lag1
# 0                                    18.481103           11.580503
# 1                                    18.481103           11.576886
# 2                                    18.481102           11.582398
# 3                                    18.481103           11.579981
# 4                                    18.481102           11.581820

# %%
ep.plot_ensemble_time_series(
    df=ensemble_arima_df, 
    iso_alpha_3="AUS",
    column="log_industry_value_added_2015_usd",
    hist_df=training_df_log_transformed)

# %%
rf_pipeline_1 = reg_d.pipe_xgb
rf_pipeline_2 = reg_d.pipe_enet

# %%
ensemble_arima_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14940 entries, 0 to 14939
# Data columns (total 17 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   iso_alpha_3                                  14940 non-null  object
#  1   future_id                                    14940 non-null  object
#  2   year                                         14940 non-null  int64
#  3   renewable_energy_consumption_pct             14940 non-null  float64
#  4   forest_area_pct                              14940 non-null  float64
#  5   log_pop_total                                14940 non-null  float64
#  6   log_gdp_2015_usd                             14940 non-null  float64
#  7   log_imports_2015_usd                         14940 non-null  float64
#  8   log_industry_value_added_2015_usd            14940 non-null  float64
#  9   log_manufacturing_value_added_2015_usd       14940 non-null  float64
#  10  log_exports_2015_usd                         14940 non-null  float64
#  11  log_gdp_2015_usd_lag1                        14940 non-null  float64
#  12  log_imports_2015_usd_lag1                    14940 non-null  float64
#  13  log_exports_2015_usd_lag1                    14940 non-null  float64
#  14  log_industry_value_added_2015_usd_lag1       14940 non-null  float64
#  15  log_manufacturing_value_added_2015_usd_lag1  14940 non-null  float64
#  16  log_pop_total_lag1                           14940 non-null  float64
# dtypes: float64(14), int64(1), object(2)
# memory usage: 1.9+ MB

# %%
# Get a df with only iso_alpha_3, income_group and region cols
iso_alpha_3_cols = ["iso_alpha_3", "income_group", "region"]
income_group_region_mapping_df = training_df_log_transformed[iso_alpha_3_cols].drop_duplicates().reset_index(drop=True)
income_group_region_mapping_df.head()
# Out:
#   iso_alpha_3         income_group                       region
# 0         ABW          High income    Latin America & Caribbean
# 1         AFG           Low income                   South Asia
# 2         AGO  Lower middle income  Africa Eastern and Southern
# 3         ALB  Upper middle income        Europe & Central Asia
# 4         ARE          High income   Middle East & North Africa

# %%
# Merge the income group and region mapping df with the ensemble df
ensemble_arima_df = pd.merge(ensemble_arima_df, income_group_region_mapping_df,
                             on="iso_alpha_3", how="left")

ensemble_arima_df.head()
# Out:
#   iso_alpha_3 future_id  year  renewable_energy_consumption_pct  \
# 0         ABW  id_ABW_1  2022                          7.762582
# 1         ABW  id_ABW_2  2022                          8.599340
# 2         ABW  id_ABW_3  2022                          8.743618
# 3         ABW  id_ABW_4  2022                          8.405104
# 4         ABW  id_ABW_5  2022                          9.454867
#
#    forest_area_pct  log_pop_total  log_gdp_2015_usd  log_imports_2015_usd  \
# 0         2.333333      11.582989         21.674358             21.494463
# 1         2.333333      11.582025         21.819419             21.494462
# 2         2.333331      11.581838         21.816428             21.494462
# 3         2.333333      11.574549         21.869997             21.494461
# 4         2.333334      11.580662         21.923628             21.494462
#
#    log_industry_value_added_2015_usd  log_manufacturing_value_added_2015_usd  \
# 0                          19.727497                               18.481103
# 1                          19.727497                               18.481104
# 2                          19.727497                               18.481103
# 3                          19.727496                               18.481102
# 4                          19.727499                               18.481103
#
#    log_exports_2015_usd  log_gdp_2015_usd_lag1  log_imports_2015_usd_lag1  \
# 0             21.492709              21.766008                  21.494462
# 1             21.492709              21.871418                  21.494463
# 2             21.492711              21.839371                  21.494462
# 3             21.492709              21.801312                  21.494464
# 4             21.492709              21.697756                  21.494463
#
#    log_exports_2015_usd_lag1  log_industry_value_added_2015_usd_lag1  \
# 0                  21.492711                               19.727497
# 1                  21.492709                               19.727500
# 2                  21.492710                               19.727500
# 3                  21.492708                               19.727498
# 4                  21.492710                               19.727497
#
#    log_manufacturing_value_added_2015_usd_lag1  log_pop_total_lag1  \
# 0                                    18.481103           11.580503
# 1                                    18.481103           11.576886
# 2                                    18.481102           11.582398
# 3                                    18.481103           11.579981
# 4                                    18.481102           11.581820
#
#   income_group                     region
# 0  High income  Latin America & Caribbean
# 1  High income  Latin America & Caribbean
# 2  High income  Latin America & Caribbean
# 3  High income  Latin America & Caribbean
# 4  High income  Latin America & Caribbean

# %%
feature_cols = [c for c in  training_df_log_transformed.columns if c not in ["iso_alpha_3", "log_total_emissions"]]

# %%
ensemble_arima_df_with_emissions = ep.predict_ensemble_emissions(ensemble_arima_df, rf_pipeline_1, feature_cols=feature_cols)
ensemble_arima_df_with_emissions.head()
# Out:
#   iso_alpha_3 future_id  year  renewable_energy_consumption_pct  \
# 0         ABW  id_ABW_1  2022                          7.762582
# 1         ABW  id_ABW_2  2022                          8.599340
# 2         ABW  id_ABW_3  2022                          8.743618
# 3         ABW  id_ABW_4  2022                          8.405104
# 4         ABW  id_ABW_5  2022                          9.454867
#
#    forest_area_pct  log_pop_total  log_gdp_2015_usd  log_imports_2015_usd  \
# 0         2.333333      11.582989         21.674358             21.494463
# 1         2.333333      11.582025         21.819419             21.494462
# 2         2.333331      11.581838         21.816428             21.494462
# 3         2.333333      11.574549         21.869997             21.494461
# 4         2.333334      11.580662         21.923628             21.494462
#
#    log_industry_value_added_2015_usd  log_manufacturing_value_added_2015_usd  \
# 0                          19.727497                               18.481103
# 1                          19.727497                               18.481104
# 2                          19.727497                               18.481103
# 3                          19.727496                               18.481102
# 4                          19.727499                               18.481103
#
#    ...  log_gdp_2015_usd_lag1  log_imports_2015_usd_lag1  \
# 0  ...              21.766008                  21.494462
# 1  ...              21.871418                  21.494463
# 2  ...              21.839371                  21.494462
# 3  ...              21.801312                  21.494464
# 4  ...              21.697756                  21.494463
#
#    log_exports_2015_usd_lag1  log_industry_value_added_2015_usd_lag1  \
# 0                  21.492711                               19.727497
# 1                  21.492709                               19.727500
# 2                  21.492710                               19.727500
# 3                  21.492708                               19.727498
# 4                  21.492710                               19.727497
#
#    log_manufacturing_value_added_2015_usd_lag1  log_pop_total_lag1  \
# 0                                    18.481103           11.580503
# 1                                    18.481103           11.576886
# 2                                    18.481102           11.582398
# 3                                    18.481103           11.579981
# 4                                    18.481102           11.581820
#
#    income_group                     region log_total_emissions  \
# 0   High income  Latin America & Caribbean            0.337802
# 1   High income  Latin America & Caribbean            0.336743
# 2   High income  Latin America & Caribbean            0.327157
# 3   High income  Latin America & Caribbean            0.334544
# 4   High income  Latin America & Caribbean            0.329355
#
#    total_emissions
# 0         1.401864
# 1         1.400379
# 2         1.387019
# 3         1.397304
# 4         1.390072
#
# [5 rows x 21 columns]

# %%
ensemble_arima_df_with_emissions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14940 entries, 0 to 14939
# Data columns (total 21 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   iso_alpha_3                                  14940 non-null  object
#  1   future_id                                    14940 non-null  object
#  2   year                                         14940 non-null  int64
#  3   renewable_energy_consumption_pct             14940 non-null  float64
#  4   forest_area_pct                              14940 non-null  float64
#  5   log_pop_total                                14940 non-null  float64
#  6   log_gdp_2015_usd                             14940 non-null  float64
#  7   log_imports_2015_usd                         14940 non-null  float64
#  8   log_industry_value_added_2015_usd            14940 non-null  float64
#  9   log_manufacturing_value_added_2015_usd       14940 non-null  float64
#  10  log_exports_2015_usd                         14940 non-null  float64
#  11  log_gdp_2015_usd_lag1                        14940 non-null  float64
#  12  log_imports_2015_usd_lag1                    14940 non-null  float64
#  13  log_exports_2015_usd_lag1                    14940 non-null  float64
#  14  log_industry_value_added_2015_usd_lag1       14940 non-null  float64
#  15  log_manufacturing_value_added_2015_usd_lag1  14940 non-null  float64
#  16  log_pop_total_lag1                           14940 non-null  float64
#  17  income_group                                 14940 non-null  object
#  18  region                                       14940 non-null  object
#  19  log_total_emissions                          14940 non-null  float32
#  20  total_emissions                              14940 non-null  float32
# dtypes: float32(2), float64(14), int64(1), object(4)
# memory usage: 2.3+ MB

# %%
# ensemble_ets_df_with_emissions = ep.predict_ensemble_emissions(ensemble_ets_df, rf_pipeline_2, feature_cols)
# ensemble_ets_df_with_emissions.head()

# %%
# ensemble_ets_df_with_emissions.info()

# %%
ep.plot_ensemble_time_series(
    df=ensemble_arima_df_with_emissions, 
    iso_alpha_3="USA",
    column="total_emissions",
    hist_df=training_df_lags)

# %%
# ep.plot_ensemble_time_series(
#     df=ensemble_ets_df_with_emissions, 
#     iso_alpha_3="USA",
#     column="total_emissions",
#     hist_df=training_df)

# %%
ensemble_arima_df_with_emissions
# Out:
#       iso_alpha_3  future_id  year  renewable_energy_consumption_pct  \
# 0             ABW   id_ABW_1  2022                          7.762582
# 1             ABW   id_ABW_2  2022                          8.599340
# 2             ABW   id_ABW_3  2022                          8.743618
# 3             ABW   id_ABW_4  2022                          8.405104
# 4             ABW   id_ABW_5  2022                          9.454867
# ...           ...        ...   ...                               ...
# 14935         ZWE   id_ZWE_6  2030                         74.601213
# 14936         ZWE   id_ZWE_7  2030                         75.665706
# 14937         ZWE   id_ZWE_8  2030                         83.941578
# 14938         ZWE   id_ZWE_9  2030                         69.560041
# 14939         ZWE  id_ZWE_10  2030                         67.846586
#
#        forest_area_pct  log_pop_total  log_gdp_2015_usd  log_imports_2015_usd  \
# 0             2.333333      11.582989         21.674358             21.494463
# 1             2.333333      11.582025         21.819419             21.494462
# 2             2.333331      11.581838         21.816428             21.494462
# 3             2.333333      11.574549         21.869997             21.494461
# 4             2.333334      11.580662         21.923628             21.494462
# ...                ...            ...               ...                   ...
# 14935        43.783796      16.735008         23.445296             22.619402
# 14936        43.783843      16.789447         23.993671             22.320624
# 14937        43.783771      16.763013         24.182068             23.280841
# 14938        43.783807      16.798374         24.688405             21.536173
# 14939        43.783791      16.738634         23.465948             23.387393
#
#        log_industry_value_added_2015_usd  \
# 0                              19.727497
# 1                              19.727497
# 2                              19.727497
# 3                              19.727496
# 4                              19.727499
# ...                                  ...
# 14935                          22.069330
# 14936                          23.491137
# 14937                          22.509743
# 14938                          22.344485
# 14939                          22.391055
#
#        log_manufacturing_value_added_2015_usd  ...  log_gdp_2015_usd_lag1  \
# 0                                   18.481103  ...              21.766008
# 1                                   18.481104  ...              21.871418
# 2                                   18.481103  ...              21.839371
# 3                                   18.481102  ...              21.801312
# 4                                   18.481103  ...              21.697756
# ...                                       ...  ...                    ...
# 14935                               21.598175  ...              23.800853
# 14936                               21.939204  ...              22.955428
# 14937                               21.407076  ...              23.633017
# 14938                               22.650236  ...              23.930905
# 14939                               19.761359  ...              23.808770
#
#        log_imports_2015_usd_lag1  log_exports_2015_usd_lag1  \
# 0                      21.494462                  21.492711
# 1                      21.494463                  21.492709
# 2                      21.494462                  21.492710
# 3                      21.494464                  21.492708
# 4                      21.494463                  21.492710
# ...                          ...                        ...
# 14935                  22.600608                  21.704939
# 14936                  23.257184                  21.457602
# 14937                  23.015279                  21.928649
# 14938                  22.321268                  20.882024
# 14939                  22.388410                  22.270692
#
#        log_industry_value_added_2015_usd_lag1  \
# 0                                   19.727497
# 1                                   19.727500
# 2                                   19.727500
# 3                                   19.727498
# 4                                   19.727497
# ...                                       ...
# 14935                               22.936651
# 14936                               21.575118
# 14937                               22.374629
# 14938                               22.065075
# 14939                               21.766744
#
#        log_manufacturing_value_added_2015_usd_lag1  log_pop_total_lag1  \
# 0                                        18.481103           11.580503
# 1                                        18.481103           11.576886
# 2                                        18.481102           11.582398
# 3                                        18.481103           11.579981
# 4                                        18.481102           11.581820
# ...                                            ...                 ...
# 14935                                    21.391455           16.771717
# 14936                                    22.559670           16.743282
# 14937                                    21.799812           16.720124
# 14938                                    21.578922           16.696266
# 14939                                    21.308507           16.725650
#
#               income_group                       region log_total_emissions  \
# 0              High income    Latin America & Caribbean            0.337802
# 1              High income    Latin America & Caribbean            0.336743
# 2              High income    Latin America & Caribbean            0.327157
# 3              High income    Latin America & Caribbean            0.334544
# 4              High income    Latin America & Caribbean            0.329355
# ...                    ...                          ...                 ...
# 14935  Lower middle income  Africa Eastern and Southern            3.940204
# 14936  Lower middle income  Africa Eastern and Southern            4.032869
# 14937  Lower middle income  Africa Eastern and Southern            3.989412
# 14938  Lower middle income  Africa Eastern and Southern            3.854266
# 14939  Lower middle income  Africa Eastern and Southern            4.054680
#
#        total_emissions
# 0             1.401864
# 1             1.400379
# 2             1.387019
# 3             1.397304
# 4             1.390072
# ...                ...
# 14935        51.429085
# 14936        56.422577
# 14937        54.023094
# 14938        47.193958
# 14939        57.666698
#
# [14940 rows x 21 columns]

# %%
initial_conditions_df = training_df_lags[training_df_lags["year"] == 2022].copy()
initial_conditions_df = initial_conditions_df.reset_index(drop=True)
initial_conditions_df = initial_conditions_df[["iso_alpha_3", "year", "total_emissions"]]
initial_conditions_df
# Out:
#     iso_alpha_3  year  total_emissions
# 0           ABW  2022         0.496683
# 1           AFG  2022        38.457458
# 2           AGO  2022       136.889648
# 3           ALB  2022         9.252882
# 4           ARE  2022       286.675891
# ..          ...   ...              ...
# 161         VNM  2022       449.692567
# 162         YEM  2022        36.119043
# 163         ZAF  2022       503.193706
# 164         ZMB  2022        77.421588
# 165         ZWE  2022        46.423948
#
# [166 rows x 3 columns]

# %%
projected_df_fixed_additive = ep.calibrate_total_emissions(
    simulated_df=ensemble_arima_df_with_emissions,
    initial_emissions_df=initial_conditions_df,
    adjustment_method="additive"
)

projected_df_fixed_additive.head()
# Out:
#   iso_alpha_3 future_id  year  renewable_energy_consumption_pct  \
# 0         ABW  id_ABW_1  2022                          7.762582
# 1         ABW  id_ABW_2  2022                          8.599340
# 2         ABW  id_ABW_3  2022                          8.743618
# 3         ABW  id_ABW_4  2022                          8.405104
# 4         ABW  id_ABW_5  2022                          9.454867
#
#    forest_area_pct  log_pop_total  log_gdp_2015_usd  log_imports_2015_usd  \
# 0         2.333333      11.582989         21.674358             21.494463
# 1         2.333333      11.582025         21.819419             21.494462
# 2         2.333331      11.581838         21.816428             21.494462
# 3         2.333333      11.574549         21.869997             21.494461
# 4         2.333334      11.580662         21.923628             21.494462
#
#    log_industry_value_added_2015_usd  log_manufacturing_value_added_2015_usd  \
# 0                          19.727497                               18.481103
# 1                          19.727497                               18.481104
# 2                          19.727497                               18.481103
# 3                          19.727496                               18.481102
# 4                          19.727499                               18.481103
#
#    ...  log_gdp_2015_usd_lag1  log_imports_2015_usd_lag1  \
# 0  ...              21.766008                  21.494462
# 1  ...              21.871418                  21.494463
# 2  ...              21.839371                  21.494462
# 3  ...              21.801312                  21.494464
# 4  ...              21.697756                  21.494463
#
#    log_exports_2015_usd_lag1  log_industry_value_added_2015_usd_lag1  \
# 0                  21.492711                               19.727497
# 1                  21.492709                               19.727500
# 2                  21.492710                               19.727500
# 3                  21.492708                               19.727498
# 4                  21.492710                               19.727497
#
#    log_manufacturing_value_added_2015_usd_lag1  log_pop_total_lag1  \
# 0                                    18.481103           11.580503
# 1                                    18.481103           11.576886
# 2                                    18.481102           11.582398
# 3                                    18.481103           11.579981
# 4                                    18.481102           11.581820
#
#    income_group                     region log_total_emissions  \
# 0   High income  Latin America & Caribbean            0.337802
# 1   High income  Latin America & Caribbean            0.336743
# 2   High income  Latin America & Caribbean            0.327157
# 3   High income  Latin America & Caribbean            0.334544
# 4   High income  Latin America & Caribbean            0.329355
#
#    total_emissions
# 0         0.496683
# 1         0.496683
# 2         0.496683
# 3         0.496683
# 4         0.496683
#
# [5 rows x 21 columns]

# %%
projected_df_fixed_multiplicative = ep.calibrate_total_emissions(
    simulated_df=ensemble_arima_df_with_emissions,
    initial_emissions_df=initial_conditions_df,
    adjustment_method="multiplicative"
)

projected_df_fixed_multiplicative.head()
# Out:
#   iso_alpha_3 future_id  year  renewable_energy_consumption_pct  \
# 0         ABW  id_ABW_1  2022                          7.762582
# 1         ABW  id_ABW_2  2022                          8.599340
# 2         ABW  id_ABW_3  2022                          8.743618
# 3         ABW  id_ABW_4  2022                          8.405104
# 4         ABW  id_ABW_5  2022                          9.454867
#
#    forest_area_pct  log_pop_total  log_gdp_2015_usd  log_imports_2015_usd  \
# 0         2.333333      11.582989         21.674358             21.494463
# 1         2.333333      11.582025         21.819419             21.494462
# 2         2.333331      11.581838         21.816428             21.494462
# 3         2.333333      11.574549         21.869997             21.494461
# 4         2.333334      11.580662         21.923628             21.494462
#
#    log_industry_value_added_2015_usd  log_manufacturing_value_added_2015_usd  \
# 0                          19.727497                               18.481103
# 1                          19.727497                               18.481104
# 2                          19.727497                               18.481103
# 3                          19.727496                               18.481102
# 4                          19.727499                               18.481103
#
#    ...  log_gdp_2015_usd_lag1  log_imports_2015_usd_lag1  \
# 0  ...              21.766008                  21.494462
# 1  ...              21.871418                  21.494463
# 2  ...              21.839371                  21.494462
# 3  ...              21.801312                  21.494464
# 4  ...              21.697756                  21.494463
#
#    log_exports_2015_usd_lag1  log_industry_value_added_2015_usd_lag1  \
# 0                  21.492711                               19.727497
# 1                  21.492709                               19.727500
# 2                  21.492710                               19.727500
# 3                  21.492708                               19.727498
# 4                  21.492710                               19.727497
#
#    log_manufacturing_value_added_2015_usd_lag1  log_pop_total_lag1  \
# 0                                    18.481103           11.580503
# 1                                    18.481103           11.576886
# 2                                    18.481102           11.582398
# 3                                    18.481103           11.579981
# 4                                    18.481102           11.581820
#
#    income_group                     region log_total_emissions  \
# 0   High income  Latin America & Caribbean            0.337802
# 1   High income  Latin America & Caribbean            0.336743
# 2   High income  Latin America & Caribbean            0.327157
# 3   High income  Latin America & Caribbean            0.334544
# 4   High income  Latin America & Caribbean            0.329355
#
#    total_emissions
# 0         0.496683
# 1         0.496683
# 2         0.496683
# 3         0.496683
# 4         0.496683
#
# [5 rows x 21 columns]

# %%
ep.plot_ensemble_time_series(
    df=projected_df_fixed_additive, 
    iso_alpha_3="USA",
    column="total_emissions",
    hist_df=training_df_lags)

# %%
ep.plot_ensemble_time_series(
    df=projected_df_fixed_multiplicative, 
    iso_alpha_3="USA",
    column="total_emissions",
    hist_df=training_df_lags)
