# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
SCRIPT_DIR_PATH = os.getcwd()
PARENT_DIR_PATH = os.path.dirname(SCRIPT_DIR_PATH)
DATA_DIR_PATH = os.path.join(PARENT_DIR_PATH, "data")
RAW_DATA_DIR_PATH = os.path.join(DATA_DIR_PATH, "raw_data")
PROCESSED_DATA_DIR_PATH = os.path.join(DATA_DIR_PATH, "processed_data")
CLIMATE_POLICY_DATA_DIR_PATH = os.path.join(RAW_DATA_DIR_PATH, "climate_policy_data")

# %%
emissions_df = pd.read_csv(os.path.join(PROCESSED_DATA_DIR_PATH, "historical_total_emission_per_country.csv"))
emissions_df.head()
# Out:
#   iso_alpha_3  year  total_emissions
# 0         ABW  1970         0.036970
# 1         ABW  1971         0.041825
# 2         ABW  1972         0.052708
# 3         ABW  1973         0.057704
# 4         ABW  1974         0.056999

# %% [markdown]
# ## Climate Policy Database

# %%
cpd_df = pd.read_excel(os.path.join(CLIMATE_POLICY_DATA_DIR_PATH, "ClimatePolicyDatabase_v2023.xlsx"))
cpd_df.head()
# Out:
#    policy_id country_iso country_update  \
# 0  211000001         ITA       Sporadic
# 1  211000002         DEU         Annual
# 2  211000003         DEU         Annual
# 3  211000004         FRA       Sporadic
# 4  211000005         KOR         Annual
#
#                                         policy_title  \
# 0  "All inclusive" Feed-in Tariff for small renew...
# 1  "Energy of the Future" monitoring process Germ...
# 2  "Energy-efficient Systems in Trade and Industr...
# 3  "Investment for the Future" Programme France (...
# 4  "Kids ISO 14000 Program" for Energy Conservati...
#
#                                          policy_name jurisdiction  \
# 0  "All inclusive" Feed-in Tariff for small renew...      Country
# 1          "Energy of the Future" monitoring process      Country
# 2  "Energy-efficient Systems in Trade and Industr...      Country
# 3              "Investment for the Future" Programme      Country
# 4  "Kids ISO 14000 Program" for Energy Conservati...      Country
#
#    supernational_region            country subnational_region  \
# 0                   NaN              Italy                NaN
# 1                   NaN            Germany                NaN
# 2                   NaN            Germany                NaN
# 3                   NaN             France                NaN
# 4                   NaN  Republic of Korea                NaN
#
#   policy_city_or_local  ... end_date high_impact policy_objective  \
# 0                  NaN  ...      NaN     Unknown       Mitigation
# 1                  NaN  ...      NaN     Unknown       Mitigation
# 2                  NaN  ...     2007     Unknown       Mitigation
# 3                  NaN  ...      NaN     Unknown       Mitigation
# 4                  NaN  ...      NaN     Unknown       Mitigation
#
#                                            reference last_update  \
# 0  https://www.iea.org/policies/4673-feed-in-tari...         NaT
# 1  https://www.bmwi.de/Redaktion/EN/Artikel/Energ...         NaT
# 2                      http://www.stromeffizienz.de/         NaT
# 3  https://www.iea.org/policies/3115-investment-f...         NaT
# 4  http://www.iso.org/iso/en/kidsiso14000/index.html         NaT
#
#   impact_indicators.comments  impact_indicators.name  impact_indicators.value  \
# 0                        NaN                     NaN                      NaN
# 1                        NaN                     NaN                      NaN
# 2                        NaN                     NaN                      NaN
# 3                        NaN                     NaN                      NaN
# 4                        NaN                     NaN                      NaN
#
#   impact_indicators.base_year impact_indicators.target_year
# 0                         NaN                           NaN
# 1                         NaN                           NaN
# 2                         NaN                           NaN
# 3                         NaN                           NaN
# 4                         NaN                           NaN
#
# [5 rows x 28 columns]

# %%
fields_to_keep = [
    "country_iso",
    "policy_name",
    "jurisdiction",
    "policy_instrument",
    "policy_type",
    "policy_status",
    "decision_date",
    "end_date"
]

cpd_df_filtered = cpd_df[fields_to_keep]
cpd_df_filtered.head()
# Out:
#   country_iso                                        policy_name jurisdiction  \
# 0         ITA  "All inclusive" Feed-in Tariff for small renew...      Country
# 1         DEU          "Energy of the Future" monitoring process      Country
# 2         DEU  "Energy-efficient Systems in Trade and Industr...      Country
# 3         FRA              "Investment for the Future" Programme      Country
# 4         KOR  "Kids ISO 14000 Program" for Energy Conservati...      Country
#
#                                    policy_instrument  \
# 0    Feed-in tariffs or premiums, Green certificates
# 1  Policy support, Institutional creation, Strate...
# 2                          Information and education
# 3                         Infrastructure investments
# 4                              Information provision
#
#                                          policy_type policy_status  \
# 0                                         Renewables    Superseded
# 1  Energy service demand reduction and resource e...      In force
# 2                                  Energy efficiency         Ended
# 3      Other low-carbon technologies and fuel switch         Ended
# 4                                  Energy efficiency      In force
#
#    decision_date end_date
# 0         2008.0      NaN
# 1         2011.0      NaN
# 2         2004.0     2007
# 3         2014.0      NaN
# 4         2005.0      NaN

# %%
cpd_df_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6273 entries, 0 to 6272
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   country_iso        6273 non-null   object
#  1   policy_name        6273 non-null   object
#  2   jurisdiction       6273 non-null   object
#  3   policy_instrument  6273 non-null   object
#  4   policy_type        6273 non-null   object
#  5   policy_status      6273 non-null   object
#  6   decision_date      6247 non-null   float64
#  7   end_date           1464 non-null   object
# dtypes: float64(1), object(7)
# memory usage: 392.2+ KB

# %%
cpd_df_filtered.jurisdiction.unique()
# Out:
# array(['Country', 'Subnational region', 'City'], dtype=object)

# %%
cpd_df_filtered.country_iso.nunique()
# Out:
# 199
